# %% [markdown]
# # Notebook to scrape data about law school faculty members
#
# Requirements:
#
#     !pip install pandas
#     !pip install bs4
#     !pip install requests
#
# Currently scrapes:
#
#     (1) Osgoode Hall Law School, York University (osgoode_bios.json)
#     (2) Faculty of Law, University of Toronto (u_toronto_bios.json)
#     (3) Lincoln Alexander School of Law, Toronto Metropolitan University (tmu_bios.json)
#     (4) Faculty of Law, Queen's University (queens_bios.json)
#     (5) Faculty of Law, Western University (western_bios.json)
#     (6) Faculty of Law, University of Windsor (windsor_bios.json)
#     (7) Bora Laskin Faculty of Law, Lakehead University (lakehead_bios.json)
#     (8) Faculty of Law - Common Law, University of Ottawa (uottawa-common_bios.json)
#     (9) Faculty of Law - Civil Law, University of Ottawa (uottawa-civil_bios.json)
#
#
# Creates combined scraped file:
#     all_bios.json
#
# Bios are in the data subfolder
#
# NOTE: Caution needed re: U Ottawa Civil Law bios. Format for bios is not consistent. Many are missing. Some are in English, some in French.
#
#
# License: [CC BY-NC 3.0](https://creativecommons.org/licenses/by-nc/3.0/)

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re
import json

# set paths
json_outpath = 'data/'

# %% [markdown]
# ### (1) Scrape Osgoode website

# %%
# Get all links for individual faculty members webpages

# load main faculty page
url = 'https://www.osgoode.yorku.ca/faculty/'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# get the main table on faculty page, convert to dataframe and clean
tables = soup.find_all('table')
df = pd.read_html(str(tables[0]))[0]
df.columns = df.columns.str.lower()
df.drop('unnamed: 0', axis=1, inplace=True)

# get all the links (hrefs) on faculty page
results = []
links = soup.find_all('a')
for link in links:
    if 'https://www.osgoode.yorku.ca/faculty-and-staff/' in link.get('href'):
        results.append(link.get('href'))

# delete every second link (b/c the links are duplicated)
results = results[::2]

# add links to the dataframe
df['href'] = results

df
# Out:
#                        name  \
# 0             Rabiat Akande
# 1             Harry Arthurs
# 2   Saptarishi Bandopadhyay
# 3       Stephanie Ben-Ishai
# 4        Benjamin L. Berger
# ..                      ...
# 73         Emily Kidd White
# 74          J. Scott Wilkie
# 75         Cynthia Williams
# 76            Alan N. Young
# 77      Frederick H. Zemans
#
#                                                 title  \
# 0                                 Assistant Professor
# 1                                  Professor Emeritus
# 2                                 Associate Professor
# 3   Professor and York University Distinguished Re...
# 4   Professor & York Research Chair in Pluralism a...
# ..                                                ...
# 73                                Assistant Professor
# 74                Distinguished Professor of Practice
# 75                                 Professor Emeritus
# 76                                 Professor Emeritus
# 77                                 Professor Emeritus
#
#                              email                telephone office  \
# 0         rakande@osgoode.yorku.ca             416-650-8422   3048
# 1        harthurs@osgoode.yorku.ca                      NaN   3015
# 2   sbandopadhyay@osgoode.yorku.ca             416-736-5488   4053
# 3       sbenishai@osgoode.yorku.ca             416-650-8239   3043
# 4         bberger@osgoode.yorku.ca             416-736-5867   3030
# ..                             ...                      ...    ...
# 73        ekwhite@osgoode.yorku.ca             416-736-5826   3033
# 74        swilkie@osgoode.yorku.ca  416-736-2100 ext. 22189   4065
# 75      cwilliams@osgoode.yorku.ca             416-736-5545   4021
# 76         ayoung@osgoode.yorku.ca                      NaN   3015
# 77        fzemans@osgoode.yorku.ca             416-736-5037   3015
#
#                                                  href
# 0   https://www.osgoode.yorku.ca/faculty-and-staff...
# 1   https://www.osgoode.yorku.ca/faculty-and-staff...
# 2   https://www.osgoode.yorku.ca/faculty-and-staff...
# 3   https://www.osgoode.yorku.ca/faculty-and-staff...
# 4   https://www.osgoode.yorku.ca/faculty-and-staff...
# ..                                                ...
# 73  https://www.osgoode.yorku.ca/faculty-and-staff...
# 74  https://www.osgoode.yorku.ca/faculty-and-staff...
# 75  https://www.osgoode.yorku.ca/faculty-and-staff...
# 76  https://www.osgoode.yorku.ca/faculty-and-staff...
# 77  https://www.osgoode.yorku.ca/faculty-and-staff...
#
# [78 rows x 6 columns]

# %%
# Scrape bios from individual faculty member webpages

# function to parse faculty member page
def parse_faculty_page(url):

    # load faculty member page
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')

    # get text from .entry-content tag
    bio = soup.find('div', {'class': 'entry-content'}).text
  
    return bio

# apply function to each row in dataframe
df['bio'] = df['href'].apply(parse_faculty_page) 

# get cleaned bios
def clean_bio(row):
    bio = row['bio']
    bio = bio.split('Graduate Research Supervision (LLM')[0]   # remove everything after 'Graduate Research Supervision (LLM, PhD):'
    if 'Research Interests:' in bio:
        listed_research = bio.split('Research Interests:')[1]   # get everything after 'Research Interests:'
        listed_research = listed_research.split('\n')[0]   
        listed_research = listed_research.replace('\xa0', ' ') # Remove non-breaking spaces
        listed_research = listed_research.replace(',', ';') 
        listed_research = listed_research.replace('.', '')
        listed_research = ' '.join(listed_research.split()) # Remove extra whitespace
        listed_research = listed_research.strip() # Remove leading and trailing whitespace

        row['listed_research_areas'] = listed_research
    else: 
        row['listed_research_areas'] = None
    bio = bio.replace('\xa0', ' ') # Remove non-breaking spaces
    bio = ' '.join(bio.split()) # Remove extra whitespace
    bio = bio.strip() # Remove leading and trailing whitespace
    bio = bio.replace('\n', ' ').strip()
    row['bio']=bio
    return row

df = df.apply(clean_bio, axis=1)

df['faculty'] = 'osgoode'

# reorder columns & drop unnecessary columns
df = df[['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas']]

# Remove non current faculty
df = df[~df['title'].str.contains('Emerit')]
df = df[~df['title'].str.contains('Distinguished Professor of Practice')]

# Save to json for future use
df.to_json(json_outpath+'osgoode_bios.json', orient='records', indent = 2)

df
# Out:
#     faculty                     name  \
# 0   osgoode            Rabiat Akande
# 2   osgoode  Saptarishi Bandopadhyay
# 3   osgoode      Stephanie Ben-Ishai
# 4   osgoode       Benjamin L. Berger
# 5   osgoode       Kate Glover Berger
# ..      ...                      ...
# 69  osgoode        Estair Van Wagner
# 70  osgoode              David Vaver
# 71  osgoode            Robert S. Wai
# 72  osgoode             Janet Walker
# 73  osgoode         Emily Kidd White
#
#                                                 title  \
# 0                                 Assistant Professor
# 2                                 Associate Professor
# 3   Professor and York University Distinguished Re...
# 4   Professor & York Research Chair in Pluralism a...
# 5                                 Associate Professor
# ..                                                ...
# 69                                Associate Professor
# 70             Professor of Intellectual Property Law
# 71                                Associate Professor
# 72                                          Professor
# 73                                Assistant Professor
#
#                              email  \
# 0         rakande@osgoode.yorku.ca
# 2   sbandopadhyay@osgoode.yorku.ca
# 3       sbenishai@osgoode.yorku.ca
# 4         bberger@osgoode.yorku.ca
# 5        kgberger@osgoode.yorku.ca
# ..                             ...
# 69     evanwagner@osgoode.yorku.ca
# 70         dvaver@osgoode.yorku.ca
# 71           rwai@osgoode.yorku.ca
# 72        jwalker@osgoode.yorku.ca
# 73        ekwhite@osgoode.yorku.ca
#
#                                                  href  \
# 0   https://www.osgoode.yorku.ca/faculty-and-staff...
# 2   https://www.osgoode.yorku.ca/faculty-and-staff...
# 3   https://www.osgoode.yorku.ca/faculty-and-staff...
# 4   https://www.osgoode.yorku.ca/faculty-and-staff...
# 5   https://www.osgoode.yorku.ca/faculty-and-staff...
# ..                                                ...
# 69  https://www.osgoode.yorku.ca/faculty-and-staff...
# 70  https://www.osgoode.yorku.ca/faculty-and-staff...
# 71  https://www.osgoode.yorku.ca/faculty-and-staff...
# 72  https://www.osgoode.yorku.ca/faculty-and-staff...
# 73  https://www.osgoode.yorku.ca/faculty-and-staff...
#
#                                                   bio  \
# 0   Professor Rabiat Akande works in the fields of...
# 2   I am an Associate Professor at Osgoode Hall La...
# 3   Professor Stephanie Ben-Ishai is a Distinguish...
# 4   Professor Benjamin L. Berger is Professor and ...
# 5   Professor Kate Glover Berger joined the facult...
# ..                                                ...
# 69  Professor Estair Van Wagner researches and tea...
# 70  David Vaver is a member of IP Osgoode and Emer...
# 71  Robert Wai has been a member of the faculty at...
# 72  Janet Walker is a full professor and past Asso...
# 73  Professor Emily Kidd White’s areas of teaching...
#
#                                 listed_research_areas
# 0   legal history; law and religion; constitutiona...
# 2   Law; history; and politics of Disasters; Inter...
# 3                            Corporate/Commercial Law
# 4   Law and Religion; Criminal and Constitutional ...
# 5                                                None
# ..                                                ...
# 69                                               None
# 70                                               None
# 71                                               None
# 72  International Litigation and Arbitration; Comp...
# 73  Legal and Political Philosophy; Constitutional...
#
# [63 rows x 7 columns]

# %% [markdown]
# ### (2) Scrape University of Toronto Website

# %%
# Define the base url for the faculty website
base_url = "https://www.law.utoronto.ca"

# Get the html content of the faculty page
response = requests.get(base_url+ '/faculty-staff/full-time-faculty')
soup = BeautifulSoup(response.content, "html.parser")

# Find all tables in soup
tables = soup.find_all("table")

# Iterate through all tables, getting 'name', 'phone' and 'email' for each faculty member
results = []
for table in tables:
    result = {}
    rows = table.find_all("tr")
    for row in rows:
        cols = row.find_all("td")
        if len(cols) > 0:
            name = cols[0].text.strip()
            phone = cols[1].text.strip()
            email = cols[2].text.strip()
            href = cols[0].find("a").get("href")
            result = {'name': name, 'email': email, 'href': base_url + href}
            results.append(result)

# convert result to df
df = pd.DataFrame(results)

df
# Out:
#                              name                       email  \
# 0                     Aidid, Abdi         a.aidid@utoronto.ca
# 1                Alarie, Benjamin      ben.alarie@utoronto.ca
# 2                    Anand, Anita     website.law@utoronto.ca
# 3                    Austin, Lisa     lisa.austin@utoronto.ca
# 4   Bédard-Rubin, Jean-Christophe  jc.bedardrubin@utoronto.ca
# ..                            ...                         ...
# 57              Valcke, Catherine        c.valcke@utoronto.ca
# 58              Valverde, Mariana      m.valverde@utoronto.ca
# 59               Waddams, Stephen       s.waddams@utoronto.ca
# 60                Weinrib, Arnold  arnold.weinrib@utoronto.ca
# 61                   Yoon, Albert     albert.yoon@utoronto.ca
#
#                                                  href
# 0   https://www.law.utoronto.ca/faculty-staff/full...
# 1   https://www.law.utoronto.ca/faculty-staff/full...
# 2   https://www.law.utoronto.ca/faculty-staff/full...
# 3   https://www.law.utoronto.ca/faculty-staff/full...
# 4   https://www.law.utoronto.ca/faculty-staff/full...
# ..                                                ...
# 57  https://www.law.utoronto.ca/faculty-staff/full...
# 58  https://www.law.utoronto.ca/faculty-staff/full...
# 59  https://www.law.utoronto.ca/faculty-staff/full...
# 60  https://www.law.utoronto.ca/faculty-staff/full...
# 61  https://www.law.utoronto.ca/faculty-staff/full...
#
# [62 rows x 3 columns]

# %%
# get faculty bios from each faculty member's page

def get_bio(row):
    bio = []
    response = requests.get(row['href'])
    soup = BeautifulSoup(response.content, "html.parser")

    texts = soup.find_all("div", class_="field")
    for text in texts:
        bio.append(text.text.strip())
    
    bio = '\n'.join(bio)
    row['bio'] = bio

    research_areas = soup.find("div", class_="bottom-right")
    
    if not research_areas:
        row['listed_research_areas'] = None
    else:
        research_areas = research_areas.get_text(separator= ',') # use this to prevent words from being concatenated
        
        if 'Research areas,' in research_areas or 'Research Areas,' in research_areas:
            research_areas = research_areas.split('Research areas,')[-1].split('Research Areas,')[-1]
            research_areas = research_areas.split('\n')[0]
            if research_areas[-1] == ',':
                research_areas = research_areas[:-1]
            research_areas = research_areas.split(',')
            research_areas = '; '.join(research_areas)
            row['listed_research_areas'] = research_areas
        else:
            row['listed_research_areas'] = None

    return row

df = df.apply(get_bio, axis=1)

# get cleaned bios
def clean_bio(bio):
    bio = bio.split('\nEducation')[0]
    bio = bio.split('\nSelected Publications')[0]
    bio = bio.split('\nSelected publications')[0]
    bio = bio.split('\nSee also Professor')[0]
    bio = bio.replace('\xa0', ' ')
    bio = bio.replace('\n', ' ').strip()
    return bio

df['bio'] = df['bio'].apply(clean_bio)

# append research areas if any
def append_research_areas(row):
    if row['listed_research_areas']:
        return row['bio'] + ' Research Interests: ' + row['listed_research_areas']
    else:
        return row['bio']

df['bio'] = df.apply(append_research_areas, axis=1)

# add faculty name
df['faculty'] = 'u_toronto'

# revise names to go from Last, first to First Last
def clean_name(name):
    name = name.split(', ')
    name = name[1] + ' ' + name[0]
    return name

df['name'] = df['name'].apply(clean_name)

# create new column for title, with NaN values
df['title'] = None

# reorder columns & drop unnecessary columns
df = df[['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas']]

# Save to json for future use
df.to_json(json_outpath + 'u_toronto_bios.json', orient='records', indent = 2)

df
# Out:
#       faculty                          name title                       email  \
# 0   u_toronto                    Abdi Aidid  None         a.aidid@utoronto.ca
# 1   u_toronto               Benjamin Alarie  None      ben.alarie@utoronto.ca
# 2   u_toronto                   Anita Anand  None     website.law@utoronto.ca
# 3   u_toronto                   Lisa Austin  None     lisa.austin@utoronto.ca
# 4   u_toronto  Jean-Christophe Bédard-Rubin  None  jc.bedardrubin@utoronto.ca
# ..        ...                           ...   ...                         ...
# 57  u_toronto              Catherine Valcke  None        c.valcke@utoronto.ca
# 58  u_toronto              Mariana Valverde  None      m.valverde@utoronto.ca
# 59  u_toronto               Stephen Waddams  None       s.waddams@utoronto.ca
# 60  u_toronto                Arnold Weinrib  None  arnold.weinrib@utoronto.ca
# 61  u_toronto                   Albert Yoon  None     albert.yoon@utoronto.ca
#
#                                                  href  \
# 0   https://www.law.utoronto.ca/faculty-staff/full...
# 1   https://www.law.utoronto.ca/faculty-staff/full...
# 2   https://www.law.utoronto.ca/faculty-staff/full...
# 3   https://www.law.utoronto.ca/faculty-staff/full...
# 4   https://www.law.utoronto.ca/faculty-staff/full...
# ..                                                ...
# 57  https://www.law.utoronto.ca/faculty-staff/full...
# 58  https://www.law.utoronto.ca/faculty-staff/full...
# 59  https://www.law.utoronto.ca/faculty-staff/full...
# 60  https://www.law.utoronto.ca/faculty-staff/full...
# 61  https://www.law.utoronto.ca/faculty-staff/full...
#
#                                                   bio  \
# 0   Assistant Professor Jackman Law BuildingRoom J...
# 1   Professor & Osler Chair in Business Law Jackma...
# 2   J.R. Kimber Chair in Investor Protection and C...
# 3   Professor, Chair in Law and Technology Jackman...
# 4   Assistant Professor 78 Queen's Park Assistant ...
# ..                                                ...
# 57  Professor Jackman Law BuildingRoom J42278 Quee...
# 58  Professor of Criminology Complete profile page...
# 59  Professor Jackman Law Building78 Queen's ParkT...
# 60  Professor (Retired) Jackman Law Building78 Que...
# 61  Professor and Michael J. Trebilcock Chair in L...
#
#                                 listed_research_areas
# 0                                                None
# 1   Economic Analysis of Law; Judicial Decision-Ma...
# 2   Business Corporations; Business Law; Economic ...
# 3   Charter of Rights; Legal Theory; National Secu...
# 4                         Canadian Constitutional Law
# ..                                                ...
# 57  Civil Law; Comparative Law; Contracts; Legal T...
# 58               Criminal Law ; Sexuality and the Law
# 59                           Contracts; Legal History
# 60                                               None
# 61                                               None
#
# [62 rows x 7 columns]

# %% [markdown]
# ### (3) Scrape Toronto Metropolitan University website

# %%
# Get api data for faculty

url = 'https://www.torontomu.ca/law/faculty-and-research/faculty/jcr:content/content/resbiographystack.data.1.json'
response = requests.get(url)
json_data = response.json()
df = pd.DataFrame(json_data['data'])

# Get api data for cross-appointed faculty
url = 'https://www.torontomu.ca/law/faculty-and-research/faculty/jcr:content/content/resbiographystack_1397589177.data.1.json'
response = requests.get(url)
json_data = response.json()
df2 = pd.DataFrame(json_data['data'])

# Combine faculty data
df = pd.concat([df, df2], ignore_index=True)

df['page']=df['page'].str.replace('/content/ryerson/','https://www.torontomu.ca/')

df
# Out:
#                                                  page         firstname  \
# 0   https://www.torontomu.ca/law/faculty-and-resea...              Idil
# 1   https://www.torontomu.ca/law/faculty-and-resea...                Ed
# 2   https://www.torontomu.ca/law/faculty-and-resea...      Hilary Evans
# 3   https://www.torontomu.ca/law/faculty-and-resea...       Christopher
# 4   https://www.torontomu.ca/law/faculty-and-resea...             Scott
# 5   https://www.torontomu.ca/law/faculty-and-resea...              Sari
# 6   https://www.torontomu.ca/law/faculty-and-resea...  Kathleen (Katie)
# 7   https://www.torontomu.ca/law/faculty-and-resea...            Graham
# 8   https://www.torontomu.ca/law/faculty-and-resea...            Angela
# 9   https://www.torontomu.ca/law/faculty-and-resea...             Avner
# 10  https://www.torontomu.ca/law/faculty-and-resea...         Alexandra
# 11  https://www.torontomu.ca/law/faculty-and-resea...        Uchechukwu
# 12  https://www.torontomu.ca/law/faculty-and-resea...          Jennifer
# 13  https://www.torontomu.ca/law/faculty-and-resea...            Joshua
# 14  https://www.torontomu.ca/law/faculty-and-resea...              Luke
# 15  https://www.torontomu.ca/law/faculty-and-resea...             Asher
# 16  https://www.torontomu.ca/law/faculty-and-resea...             Pnina
# 17  https://www.torontomu.ca/law/faculty-and-resea...        Timothy J.
# 18  https://www.torontomu.ca/law/faculty-and-resea...               Gil
# 19  https://www.torontomu.ca/law/faculty-and-resea...         Alexandra
#
#             lastname                                              title  \
# 0               Atak                                Associate Professor
# 1     Béchard-Torres                                Assistant Professor
# 2            Cameron                                Assistant Professor
# 3   Campbell-Duruflé                                Assistant Professor
# 4             Franks                                Assistant Professor
# 5             Graben  Associate Dean Research &amp; Graduate Studies...
# 6            Hammond                                Assistant Professor
# 7             Hudson                Associate Dean, Academic; Professor
# 8                Lee                                Assistant Professor
# 9              Levin                                          Professor
# 10          Mogyoros                                Assistant Professor
# 11            Ngwaba                                Assistant Professor
# 12            Orange                                Assistant Professor
# 13  Sealy-Harrington                                Assistant Professor
# 14            Taylor                                Assistant Professor
# 15            Alkoby                                Associate Professor
# 16      Alon-Shenker                                Associate Professor
# 17           Bartkiw                                Associate Professor
# 18               Lan                                Associate Professor
# 19            Orlova                                          Professor
#
#                               email  \
# 0            idil.atak@torontomu.ca
# 1                               NaN
# 2       h.evanscameron@torontomu.ca
# 3                               NaN
# 4         scott.franks@torontomu.ca
# 5              sgraben@torontomu.ca
# 6     kathleen.hammond@torontomu.ca
# 7        graham.hudson@torontomu.ca
# 8               angela@torontomu.ca
# 9          avner.levin@torontomu.ca
# 10  alexandra.mogyoros@torontomu.ca
# 11         uche.ngwaba@torontomu.ca
# 12     jennifer.orange@torontomu.ca
# 13        joshua.sealy@torontomu.ca
# 14         luke.taylor@torontomu.ca
# 15             aalkoby@torontomu.ca
# 16          pnina.alon@torontomu.ca
# 17            tbartkiw@torontomu.ca
# 18                glan@torontomu.ca
# 19             aorlova@torontomu.ca
#
#                                            department  \
# 0                     Lincoln Alexander School of Law
# 1                     Lincoln Alexander School of Law
# 2                     Lincoln Alexander School of Law
# 3                     Lincoln Alexander School of Law
# 4                     Lincoln Alexander School of Law
# 5                     Lincoln Alexander School of Law
# 6                     Lincoln Alexander School of Law
# 7                     Lincoln Alexander School of Law
# 8                     Lincoln Alexander School of Law
# 9   Lincoln Alexander School of Law and the busine...
# 10                    Lincoln Alexander School of Law
# 11                    Lincoln Alexander School of Law
# 12                    Lincoln Alexander School of Law
# 13                    Lincoln Alexander School of Law
# 14                    Lincoln Alexander School of Law
# 15  Law and Business Department at TRSM; Lincoln A...
# 16  Department of Law &amp; Business at the Ted Ro...
# 17  HR Management &amp; Organizational Behaviour a...
# 18  Law and Business at TRSM; Lincoln Alexander Sc...
# 19  Department of Criminology in the Faculty of Ar...
#
#                                        specialization  \
# 0   Irregular migration, refugee protection, secur...
# 1   Corporate law; contract law; constitutional la...
# 2   Refugee law; administrative law; memory; risk ...
# 3   International law, environmental law, human ri...
# 4   Aboriginal Law; Indigenous legal orders; criti...
# 5   Environmental law, Aboriginal Law, Gender, Res...
# 6   Science and technology law; health law; family...
# 7   Socio-legal studies, access to justice, crimin...
# 8   Law and technology; food and agriculture law; ...
# 9   Legal regulation and protection of privacy and...
# 10  Intellectual property; law and technology; pri...
# 11  Public health and human rights, international ...
# 12  Human rights, international law, organizationa...
# 13  Critical race theory, critical disability theo...
# 14  Family law, employment law, legal history, law...
# 15  Global governance, corporate social responsibi...
# 16  Employment law; labour law; human rights; work...
# 17  labour and employment law and policy; industri...
# 18  International business law; government regulat...
# 19  Criminal and international criminal law; human...
#
#                                        thumbnailImage  \
# 0     /content/dam/law/faculty/Idil_Atak_1200x900.jpg
# 1   /content/dam/law/faculty/Ed-Bechard-Torres-120...
# 2   /content/dam/law/faculty/hilary-evans-cameron.jpg
# 3   /content/dam/law/faculty/Christopher_Campbell-...
# 4   /content/dam/law/faculty/Scott_Franks_1200x900...
# 5         /content/dam/law/images/sari-graben-new.jpg
# 6       /content/dam/law/faculty/kathleen-hammond.jpg
# 7      /content/dam/law/faculty/Graham_Hudson_new.jpg
# 8             /content/dam/law/faculty/angela-lee.jpg
# 9            /content/dam/law/faculty/avner-levin.jpg
# 10    /content/dam/law/faculty/alexandra-mogyoros.jpg
# 11  /content/dam/law/faculty/Uche_Ngwaba_1200x900.jpg
# 12       /content/dam/law/faculty/jennifer_orange.png
# 13  /content/dam/law/faculty/Joshua_Sealy-Harringt...
# 14  /content/dam/law/faculty/Luke_Taylor_1200x900.jpg
# 15          /content/dam/law/faculty/asher-alkoby.jpg
# 16          /content/dam/law/faculty/pnina_737wv2.jpg
# 17          /content/dam/law/faculty/bartkiw_737w.jpg
# 18              /content/dam/law/faculty/lan_737w.jpg
# 19           /content/dam/law/faculty/orlova_737w.jpg
#
#                            thumbnailAltText  \
# 0                                 Idil Atak
# 1                         Ed Béchard-Torres
# 2                      Hilary Evans Cameron
# 3              Christopher Campbell-Duruflé
# 4                              Scott Franks
# 5                               Sari Graben
# 6                          Kathleen Hammond
# 7        Graham Hudson, Associate Professor
# 8                                Angela Lee
# 9                               Avner Levin
# 10                       Alexandra Mogyoros
# 11                        Uchechukwu Ngwaba
# 12                          Jennifer Orange
# 13                  Joshua Sealy-Harrington
# 14                              Luke Taylor
# 15                             Asher Alkoby
# 16  Pnina Alon-Shenker, Associate Professor
# 17  Timothy J. Bartkiw, Associate Professor
# 18             Gil Lan, Associate Professor
# 19    Alexandra Orlova, Associate Professor
#
#                                                  tags
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'tagId': 'Positions-Titles:Professor', 'tagT...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN

# %%
# Get faculty bios from faculty pages

def get_bio(page):
    response = requests.get(page)
    soup = BeautifulSoup(response.text, 'html.parser')

    # get text from the first div that includes .resText
    bio = soup.find('div', {'class': 'resText'}).text

    # remove newlines
    bio = bio.replace('\n', ' ')

    # remove multiple spaces
    bio = ' '.join(bio.split())

    bio = bio.strip()

    time.sleep(0.25)

    return bio

df['bio'] = df['page'].apply(get_bio)

# rename page
df = df.rename(columns={'page': 'href'})

# combine first and last name
df['name'] = df['firstname'] + ' ' + df['lastname']

# Append specializations to bio
def append_specialization(row):
    bio = row['bio']
    specialization = row['specialization']
    if specialization:
        bio = bio + ' Research Interests: ' + specialization
    return bio

df['bio'] = df.apply(append_specialization, axis=1)

# rename specialization column
df = df.rename(columns={'specialization': 'listed_research_areas'})

df['faculty'] = 'tmu'

# reorder columns & drop unnecessary columns
df = df[['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas']]

# Manually add the dean
faculty = 'tmu'
name = 'Donna Young'
title = 'Dean'
email = 'deanoflaw@torontomu.ca'
hfref = 'https://www.torontomu.ca/law/about/our-dean/'
bio = 'Donna E. Young is the Founding Dean of the Lincoln Alexander School of Law. Before assuming her deanship, she was the President William McKinley Distinguished Professor of Law and Public Policy at Albany Law School and a joint faculty member at the University at Albany\'s Department of Women\'s, Gender, and Sexuality Studies. Her teaching and scholarship focus on law and inequality, race and gender discrimination, and academic freedom and university governance. She has taught courses in Criminal Law, Employment Law; U.S. Federal Civil Procedure; Gender and Work; and Race, Rape Culture, and Law. Dean Young is much sought after as a speaker and has been invited to present her work at conferences and other venues around the world. She has been a staff member at the American Association of University Professors\' (AAUP) Department of Academic Freedom, Tenure, and Governance, in Washington, D.C. and was a member of the AAUP\'s Committee A, the preeminent national body setting standards and investigating academic freedom disputes in the United States. She has been a Fellow at Cornell Law School\'s Gender, Sexuality, and Family Project; a Visiting Scholar at Osgoode Hall Law School\'s Institute of Feminist Legal Studies; an Associate in Law at Columbia Law School; a Visiting Scholar at the Faculty of Law at Roma Tre University in Rome, Italy; and a consultant to the International Development Law Organization for whom she traveled to Uganda to conduct field research on the relationship between gender inequality and law in the context of the HIV/AIDS crisis. Dean Young\'s previous professional experiences include articling at Cornish Roland - a labour law firm in Toronto; serving as a consultant with the Ontario Human Rights Commission; and working as a researcher with the NYC Office of Labor Relations. She is admitted to practice in New York State. Research interests: Criminal Law; Employment Law; US Federal Civil Procedure; Antidiscrimination Law and Civil Rights; Critical Race Theory and Feminist Legal Theory; Academic freedom and due process, and university governance; Title IX'
listed_research_areas = 'Criminal Law; Employment Law; US Federal Civil Procedure; Antidiscrimination Law and Civil Rights; Critical Race Theory and Feminist Legal Theory; Academic freedom and due process, and university governance; Title IX'
df2 = pd.DataFrame([[faculty, name, title, email, hfref, bio, listed_research_areas]], columns=['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas'])
df = pd.concat([df, df2], ignore_index=True)

# Save to json for future use
df.to_json(json_outpath + 'tmu_bios.json', orient='records', indent = 2)

df
# Out:
#    faculty                          name  \
# 0      tmu                     Idil Atak
# 1      tmu             Ed Béchard-Torres
# 2      tmu          Hilary Evans Cameron
# 3      tmu  Christopher Campbell-Duruflé
# 4      tmu                  Scott Franks
# 5      tmu                   Sari Graben
# 6      tmu      Kathleen (Katie) Hammond
# 7      tmu                 Graham Hudson
# 8      tmu                    Angela Lee
# 9      tmu                   Avner Levin
# 10     tmu            Alexandra Mogyoros
# 11     tmu             Uchechukwu Ngwaba
# 12     tmu               Jennifer Orange
# 13     tmu       Joshua Sealy-Harrington
# 14     tmu                   Luke Taylor
# 15     tmu                  Asher Alkoby
# 16     tmu            Pnina Alon-Shenker
# 17     tmu            Timothy J. Bartkiw
# 18     tmu                       Gil Lan
# 19     tmu              Alexandra Orlova
# 20     tmu                   Donna Young
#
#                                                 title  \
# 0                                 Associate Professor
# 1                                 Assistant Professor
# 2                                 Assistant Professor
# 3                                 Assistant Professor
# 4                                 Assistant Professor
# 5   Associate Dean Research &amp; Graduate Studies...
# 6                                 Assistant Professor
# 7                 Associate Dean, Academic; Professor
# 8                                 Assistant Professor
# 9                                           Professor
# 10                                Assistant Professor
# 11                                Assistant Professor
# 12                                Assistant Professor
# 13                                Assistant Professor
# 14                                Assistant Professor
# 15                                Associate Professor
# 16                                Associate Professor
# 17                                Associate Professor
# 18                                Associate Professor
# 19                                          Professor
# 20                                               Dean
#
#                               email  \
# 0            idil.atak@torontomu.ca
# 1                               NaN
# 2       h.evanscameron@torontomu.ca
# 3                               NaN
# 4         scott.franks@torontomu.ca
# 5              sgraben@torontomu.ca
# 6     kathleen.hammond@torontomu.ca
# 7        graham.hudson@torontomu.ca
# 8               angela@torontomu.ca
# 9          avner.levin@torontomu.ca
# 10  alexandra.mogyoros@torontomu.ca
# 11         uche.ngwaba@torontomu.ca
# 12     jennifer.orange@torontomu.ca
# 13        joshua.sealy@torontomu.ca
# 14         luke.taylor@torontomu.ca
# 15             aalkoby@torontomu.ca
# 16          pnina.alon@torontomu.ca
# 17            tbartkiw@torontomu.ca
# 18                glan@torontomu.ca
# 19             aorlova@torontomu.ca
# 20           deanoflaw@torontomu.ca
#
#                                                  href  \
# 0   https://www.torontomu.ca/law/faculty-and-resea...
# 1   https://www.torontomu.ca/law/faculty-and-resea...
# 2   https://www.torontomu.ca/law/faculty-and-resea...
# 3   https://www.torontomu.ca/law/faculty-and-resea...
# 4   https://www.torontomu.ca/law/faculty-and-resea...
# 5   https://www.torontomu.ca/law/faculty-and-resea...
# 6   https://www.torontomu.ca/law/faculty-and-resea...
# 7   https://www.torontomu.ca/law/faculty-and-resea...
# 8   https://www.torontomu.ca/law/faculty-and-resea...
# 9   https://www.torontomu.ca/law/faculty-and-resea...
# 10  https://www.torontomu.ca/law/faculty-and-resea...
# 11  https://www.torontomu.ca/law/faculty-and-resea...
# 12  https://www.torontomu.ca/law/faculty-and-resea...
# 13  https://www.torontomu.ca/law/faculty-and-resea...
# 14  https://www.torontomu.ca/law/faculty-and-resea...
# 15  https://www.torontomu.ca/law/faculty-and-resea...
# 16  https://www.torontomu.ca/law/faculty-and-resea...
# 17  https://www.torontomu.ca/law/faculty-and-resea...
# 18  https://www.torontomu.ca/law/faculty-and-resea...
# 19  https://www.torontomu.ca/law/faculty-and-resea...
# 20       https://www.torontomu.ca/law/about/our-dean/
#
#                                                   bio  \
# 0   Dr. Idil Atak is an associate professor at the...
# 1   Ed Béchard-Torres is an assistant professor in...
# 2   A former litigator, Hilary Evans Cameron repre...
# 3   Christopher Campbell-Duruflé’s work focuses on...
# 4   Scott Franks is an assistant professor in the ...
# 5   Sari Graben’s teaching and research focuses on...
# 6   Katie Hammond is an assistant professor in the...
# 7   Graham Hudson is an Associate Professor and As...
# 8   Angela Lee joined the Lincoln Alexander School...
# 9   Avner Levin is a professor at Toronto Metropol...
# 10  Alexandra Mogyoros is an acting assistant prof...
# 11  Prior to joining the Lincoln Alexander School ...
# 12  Jennifer Orange is an assistant professor in t...
# 13  Twitter: @joshuasealy, external link Joshua Se...
# 14  Prior to his postgraduate studies, Luke Taylor...
# 15  Asher Alkoby is an associate professor in the ...
# 16  Pnina Alon-Shenker is an associate professor i...
# 17  Timothy J. Bartkiw is an associate professor i...
# 18  Gil Lan is an associate professor in the Linco...
# 19  Alexandra Orlova received her PhD in law from ...
# 20  Donna E. Young is the Founding Dean of the Lin...
#
#                                 listed_research_areas
# 0   Irregular migration, refugee protection, secur...
# 1   Corporate law; contract law; constitutional la...
# 2   Refugee law; administrative law; memory; risk ...
# 3   International law, environmental law, human ri...
# 4   Aboriginal Law; Indigenous legal orders; criti...
# 5   Environmental law, Aboriginal Law, Gender, Res...
# 6   Science and technology law; health law; family...
# 7   Socio-legal studies, access to justice, crimin...
# 8   Law and technology; food and agriculture law; ...
# 9   Legal regulation and protection of privacy and...
# 10  Intellectual property; law and technology; pri...
# 11  Public health and human rights, international ...
# 12  Human rights, international law, organizationa...
# 13  Critical race theory, critical disability theo...
# 14  Family law, employment law, legal history, law...
# 15  Global governance, corporate social responsibi...
# 16  Employment law; labour law; human rights; work...
# 17  labour and employment law and policy; industri...
# 18  International business law; government regulat...
# 19  Criminal and international criminal law; human...
# 20  Criminal Law; Employment Law; US Federal Civil...

# %% [markdown]
# ### (4) Scrape Queen's University Faculty Bios

# %%
# get list of faculty and their pages

# Define the base url for the faculty website
base_url = "https://law.queensu.ca"

# Get the html content of the faculty page
response = requests.get(base_url+ '/directory')
soup = BeautifulSoup(response.content, "html.parser")

# Find all divs that include 'person-type-1 views-row', including classes that include other information at the beginning of the string 
profs = soup.find_all('div', {'class': re.compile('person-type-1 views-row')})

results = []
for prof in profs:
    result = {}
    result['faculty'] = 'queens'
    result['name'] = prof.find('h2').text.strip()
    result['name'] = result['name'].split(',')[0]
    if prof.find('h3'):
        result['title'] = prof.find('h3').text.strip()
    else:
        result['title'] = None
    result['href'] = base_url + prof.find('a')['href']
    results.append(result)
    
# convert to df
df = pd.DataFrame(results)
df
# Out:
#    faculty                   name  \
# 0   queens           Mark Walters
# 1   queens           Sharry Aiken
# 2   queens             Bita Amani
# 3   queens          Martha Bailey
# 4   queens        Beverley Baines
# 5   queens       Nicholas C. Bala
# 6   queens            Kevin Banks
# 7   queens        Lindsay Borrows
# 8   queens     Richard Chaykowski
# 9   queens           Samuel Dahan
# 10  queens         Benjamin Ewing
# 11  queens         David Freedman
# 12  queens             Colin Grey
# 13  queens         Gail Henderson
# 14  queens            Ardi Imseis
# 15  queens          Joshua Karton
# 16  queens             Lisa Kelly
# 17  queens              Lisa Kerr
# 18  queens         Mohamed Khimji
# 19  queens            Alyssa King
# 20  queens           Erik Knutsen
# 21  queens          Will Kymlicka
# 22  queens         Kathleen Lahey
# 23  queens           Nicolas Lamp
# 24  queens             David Lyon
# 25  queens         Cherie Metcalf
# 26  queens            Bruce Pardy
# 27  queens        Patricia Peppin
# 28  queens          Michael Pratt
# 29  queens        Darryl Robinson
# 30  queens             Don Stuart
# 31  queens    Christine Sypnowich
# 32  queens            Jean Thomas
# 33  queens         Sabine Tsuruda
# 34  queens  Ashwini Vasanthakumar
# 35  queens        Grégoire Webber
# 36  queens          Jacob Weinrib
# 37  queens          Noah Weisbord
# 38  queens          Robert Yalden
#
#                                                 title  \
# 0                           Dean and Professor of Law
# 1                                 Associate Professor
# 2                                 Associate Professor
# 3                                           Professor
# 4                                           Professor
# 5   William R. Lederman Distinguished University P...
# 6   Associate Dean (Faculty), Associate Professor;...
# 7                                 Assistant Professor
# 8   Professor, MIR Program Director, Faculty of Ar...
# 9                                 Assistant Professor
# 10                                Assistant Professor
# 11                                Associate Professor
# 12                                Associate Professor
# 13                                Associate Professor
# 14                                Assistant Professor
# 15                                Associate Professor
# 16                                Assistant Professor
# 17                                Associate Professor
# 18  Associate Dean (Academic Policy), David Allgoo...
# 19                                Assistant Professor
# 20                                          Professor
# 21                                               None
# 22  Professor, Queen's National Scholar, and Patri...
# 23                                Associate Professor
# 24  Director, Surveillance Studies Centre, Queen's...
# 25                                Associate Professor
# 26                                          Professor
# 27                                          Professor
# 28                                Associate Professor
# 29  Associate Dean (Graduate Studies and Research)...
# 30                                               None
# 31                                               None
# 32                                Associate Professor
# 33                                Assistant Professor
# 34  Associate Professor and Queen’s National Schol...
# 35  Canada Research Chair in Public Law and Philos...
# 36                                Associate Professor
# 37                                Associate Professor
# 38   Sigurdson Professor in Corporate Law and Finance
#
#                                                  href
# 0      https://law.queensu.ca/directory/_mark-walters
# 1      https://law.queensu.ca/directory/sharryn-aiken
# 2         https://law.queensu.ca/directory/bita-amani
# 3      https://law.queensu.ca/directory/martha-bailey
# 4    https://law.queensu.ca/directory/beverley-baines
# 5    https://law.queensu.ca/directory/nicholas-c-bala
# 6        https://law.queensu.ca/directory/kevin-banks
# 7    https://law.queensu.ca/directory/lindsay-borrows
# 8   https://law.queensu.ca/directory/richard-chayk...
# 9       https://law.queensu.ca/directory/samuel-dahan
# 10    https://law.queensu.ca/directory/benjamin-ewing
# 11    https://law.queensu.ca/directory/david-freedman
# 12        https://law.queensu.ca/directory/colin-grey
# 13    https://law.queensu.ca/directory/gail-henderson
# 14       https://law.queensu.ca/directory/ardi-imseis
# 15     https://law.queensu.ca/directory/joshua-karton
# 16        https://law.queensu.ca/directory/lisa-kelly
# 17         https://law.queensu.ca/directory/lisa-kerr
# 18    https://law.queensu.ca/directory/mohamed-khimji
# 19       https://law.queensu.ca/directory/alyssa-king
# 20      https://law.queensu.ca/directory/erik-knutsen
# 21  https://law.queensu.ca/directory/will-kymlicka...
# 22    https://law.queensu.ca/directory/kathleen-lahey
# 23      https://law.queensu.ca/directory/nicolas-lamp
# 24        https://law.queensu.ca/directory/david-lyon
# 25    https://law.queensu.ca/directory/cherie-metcalf
# 26       https://law.queensu.ca/directory/bruce-pardy
# 27   https://law.queensu.ca/directory/patricia-peppin
# 28     https://law.queensu.ca/directory/michael-pratt
# 29   https://law.queensu.ca/directory/darryl-robinson
# 30        https://law.queensu.ca/directory/don-stuart
# 31  https://law.queensu.ca/directory/christine-syp...
# 32       https://law.queensu.ca/directory/jean-thomas
# 33    https://law.queensu.ca/directory/sabine-tsuruda
# 34  https://law.queensu.ca/directory/ashwini-vasan...
# 35   https://law.queensu.ca/directory/gregoire-webber
# 36     https://law.queensu.ca/directory/jacob-weinrib
# 37   https://law.queensu.ca/directory/noah-weisbord-0
# 38     https://law.queensu.ca/directory/robert-yalden

# %%
def get_bio(row):
    response = requests.get(row['href'])
    soup = BeautifulSoup(response.text, 'html.parser')

    # get text from the first div class 'node__content'
    bio = soup.find('div', {'class': 'node__content'})
    if bio:
        bio = bio.text
    else:
        # check if there is a div class "people-about"
        bio = soup.find('div', {'class': 'people-about'})
        if bio:
            bio = bio.text
        else:
            bio = None

    # if there are two divs with class 'node__content', get the second one
    if len(soup.find_all('div', {'class': 'node__content'})) > 1:
        bio2 = soup.find_all('div', {'class': 'node__content'})[1].text
    else:
        bio2 = None
    
    # append research_areas to bio
    if bio2:
        bio = bio + ' ' + bio2

    # get email        
    if bio2:
        if '@queensu.ca' in bio2:
            email = bio2.split('@queensu.ca')[0].split('\n')[-1] + '@queensu.ca'
            email = email.strip()
        else:
            email = None
    else:
        if bio: 
            if '@queensu.ca' in bio:
                email = bio2.split('@queensu.ca')[0].split('\n')[-1] + '@queensu.ca'
                email = email.strip()
            else:
                email = None
        else:
            email = None
    
    if bio:
        bio = bio.replace('\n', ' ')

        # remove non-breaking spaces
        bio = bio.replace(u'\xa0', u' ')

        # remove multiple spaces
        bio = ' '.join(bio.split())

        bio = bio.strip()

    # get areas of research expertise if listed by lookin for div class: "field field--name-field-teaching-and-research field--type-entity-reference field--label-above"
    research_areas = soup.find('div', {'class': 'field field--name-field-teaching-and-research field--type-entity-reference field--label-above'})
    if research_areas:
        research_areas = research_areas.text
        research_areas = research_areas.replace('Teaching and Research Topics', ' ')
        research_areas = research_areas.replace(u'\xa0', '; ')
        research_areas = research_areas.replace('\n', '; ')
        research_areas = research_areas.replace('/', '; ')
        research_areas = [x.strip() for x in research_areas.split(';') if x.strip()]
        research_areas = '; '.join(research_areas).lstrip(';')
        research_areas = research_areas.replace('’', "'")
        research_areas = research_areas.replace("`", "'")
        research_areas = research_areas.title().strip()
        research_areas = research_areas.replace('Children\'S', 'Children\'s')
    else:
        research_areas = None

    row['email']=email
    row['bio']=bio
    row['listed_research_areas']=research_areas

    return row

df = df.apply(get_bio, axis=1)

# Change order of columns
df = df[['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas']]

# Save to json for future use
df.to_json(json_outpath + 'queens_bios.json', orient='records', indent = 2)

df
# Out:
#    faculty                   name  \
# 0   queens           Mark Walters
# 1   queens           Sharry Aiken
# 2   queens             Bita Amani
# 3   queens          Martha Bailey
# 4   queens        Beverley Baines
# 5   queens       Nicholas C. Bala
# 6   queens            Kevin Banks
# 7   queens        Lindsay Borrows
# 8   queens     Richard Chaykowski
# 9   queens           Samuel Dahan
# 10  queens         Benjamin Ewing
# 11  queens         David Freedman
# 12  queens             Colin Grey
# 13  queens         Gail Henderson
# 14  queens            Ardi Imseis
# 15  queens          Joshua Karton
# 16  queens             Lisa Kelly
# 17  queens              Lisa Kerr
# 18  queens         Mohamed Khimji
# 19  queens            Alyssa King
# 20  queens           Erik Knutsen
# 21  queens          Will Kymlicka
# 22  queens         Kathleen Lahey
# 23  queens           Nicolas Lamp
# 24  queens             David Lyon
# 25  queens         Cherie Metcalf
# 26  queens            Bruce Pardy
# 27  queens        Patricia Peppin
# 28  queens          Michael Pratt
# 29  queens        Darryl Robinson
# 30  queens             Don Stuart
# 31  queens    Christine Sypnowich
# 32  queens            Jean Thomas
# 33  queens         Sabine Tsuruda
# 34  queens  Ashwini Vasanthakumar
# 35  queens        Grégoire Webber
# 36  queens          Jacob Weinrib
# 37  queens          Noah Weisbord
# 38  queens          Robert Yalden
#
#                                                 title  \
# 0                           Dean and Professor of Law
# 1                                 Associate Professor
# 2                                 Associate Professor
# 3                                           Professor
# 4                                           Professor
# 5   William R. Lederman Distinguished University P...
# 6   Associate Dean (Faculty), Associate Professor;...
# 7                                 Assistant Professor
# 8   Professor, MIR Program Director, Faculty of Ar...
# 9                                 Assistant Professor
# 10                                Assistant Professor
# 11                                Associate Professor
# 12                                Associate Professor
# 13                                Associate Professor
# 14                                Assistant Professor
# 15                                Associate Professor
# 16                                Assistant Professor
# 17                                Associate Professor
# 18  Associate Dean (Academic Policy), David Allgoo...
# 19                                Assistant Professor
# 20                                          Professor
# 21                                               None
# 22  Professor, Queen's National Scholar, and Patri...
# 23                                Associate Professor
# 24  Director, Surveillance Studies Centre, Queen's...
# 25                                Associate Professor
# 26                                          Professor
# 27                                          Professor
# 28                                Associate Professor
# 29  Associate Dean (Graduate Studies and Research)...
# 30                                               None
# 31                                               None
# 32                                Associate Professor
# 33                                Assistant Professor
# 34  Associate Professor and Queen’s National Schol...
# 35  Canada Research Chair in Public Law and Philos...
# 36                                Associate Professor
# 37                                Associate Professor
# 38   Sigurdson Professor in Corporate Law and Finance
#
#                                email  \
# 0            mark.walters@queensu.ca
# 1                   aiken@queensu.ca
# 2                  amanib@queensu.ca
# 3                 baileym@queensu.ca
# 4                 bainesb@queensu.ca
# 5                    bala@queensu.ca
# 6                  banksk@queensu.ca
# 7         lindsay.borrows@queensu.ca
# 8                chaykows@queensu.ca
# 9            samuel.dahan@queensu.ca
# 10         benjamin.ewing@queensu.ca
# 11         david.freedman@queensu.ca
# 12             colin.grey@queensu.ca
# 13         gail.henderson@queensu.ca
# 14               a.imseis@queensu.ca
# 15          joshua.karton@queensu.ca
# 16             lisa.kelly@queensu.ca
# 17              lisa.kerr@queensu.ca
# 18         mohamed.khimji@queensu.ca
# 19            alyssa.king@queensu.ca
# 20                knutsen@queensu.ca
# 21                              None
# 22                   kal2@queensu.ca
# 23           nicolas.lamp@queensu.ca
# 24                  lyond@queensu.ca
# 25               metcalfc@queensu.ca
# 26                 pardyb@queensu.ca
# 27                peppinp@queensu.ca
# 28                m.pratt@queensu.ca
# 29        darryl.robinson@queensu.ca
# 30                stuartd@queensu.ca
# 31                              None
# 32            jean.thomas@queensu.ca
# 33         sabine.tsuruda@queensu.ca
# 34  ashwini.vasanthakumar@queensu.ca
# 35        gregoire.webber@queensu.ca
# 36          jacob.weinrib@queensu.ca
# 37          noah.weisbord@queensu.ca
# 38          robert.yalden@queensu.ca
#
#                                                  href  \
# 0      https://law.queensu.ca/directory/_mark-walters
# 1      https://law.queensu.ca/directory/sharryn-aiken
# 2         https://law.queensu.ca/directory/bita-amani
# 3      https://law.queensu.ca/directory/martha-bailey
# 4    https://law.queensu.ca/directory/beverley-baines
# 5    https://law.queensu.ca/directory/nicholas-c-bala
# 6        https://law.queensu.ca/directory/kevin-banks
# 7    https://law.queensu.ca/directory/lindsay-borrows
# 8   https://law.queensu.ca/directory/richard-chayk...
# 9       https://law.queensu.ca/directory/samuel-dahan
# 10    https://law.queensu.ca/directory/benjamin-ewing
# 11    https://law.queensu.ca/directory/david-freedman
# 12        https://law.queensu.ca/directory/colin-grey
# 13    https://law.queensu.ca/directory/gail-henderson
# 14       https://law.queensu.ca/directory/ardi-imseis
# 15     https://law.queensu.ca/directory/joshua-karton
# 16        https://law.queensu.ca/directory/lisa-kelly
# 17         https://law.queensu.ca/directory/lisa-kerr
# 18    https://law.queensu.ca/directory/mohamed-khimji
# 19       https://law.queensu.ca/directory/alyssa-king
# 20      https://law.queensu.ca/directory/erik-knutsen
# 21  https://law.queensu.ca/directory/will-kymlicka...
# 22    https://law.queensu.ca/directory/kathleen-lahey
# 23      https://law.queensu.ca/directory/nicolas-lamp
# 24        https://law.queensu.ca/directory/david-lyon
# 25    https://law.queensu.ca/directory/cherie-metcalf
# 26       https://law.queensu.ca/directory/bruce-pardy
# 27   https://law.queensu.ca/directory/patricia-peppin
# 28     https://law.queensu.ca/directory/michael-pratt
# 29   https://law.queensu.ca/directory/darryl-robinson
# 30        https://law.queensu.ca/directory/don-stuart
# 31  https://law.queensu.ca/directory/christine-syp...
# 32       https://law.queensu.ca/directory/jean-thomas
# 33    https://law.queensu.ca/directory/sabine-tsuruda
# 34  https://law.queensu.ca/directory/ashwini-vasan...
# 35   https://law.queensu.ca/directory/gregoire-webber
# 36     https://law.queensu.ca/directory/jacob-weinrib
# 37   https://law.queensu.ca/directory/noah-weisbord-0
# 38     https://law.queensu.ca/directory/robert-yalden
#
#                                                   bio  \
# 0   Mark Walters began his five-year term as Dean ...
# 1   Sharry Aiken is an Associate Professor at Quee...
# 2   Dr. Bita Amani is an Associate Professor of La...
# 3   Martha Bailey, is a Professor of law at Queen’...
# 4   Beverley Baines is a Professor of Public and C...
# 5   Nicholas (Nick) Bala is an internationally rec...
# 6   Biography Kevin Banks is Associate Professor o...
# 7   Lindsay Borrows is an Assistant Professor at Q...
# 8   Richard Chaykowski received his PhD from Corne...
# 9   Samuel Dahan is professor of law at Queen’s Un...
# 10  Benjamin Ewing is an Assistant Professor at Qu...
# 11  David Freedman is an Associate Professor at Qu...
# 12  Colin Grey joined the Faculty of Law at Queen’...
# 13  Professor Gail Henderson joined Queen's Univer...
# 14  Ardi Imseis is interested in the intersection ...
# 15  On leave in 2022-23 Joshua Karton teaches and ...
# 16  Lisa M. Kelly is an Assistant Professor at Que...
# 17  Lisa Kerr teaches courses on criminal law, evi...
# 18  Mohamed Khimji is currently serving as the Ass...
# 19  Alyssa King studies how adjudicators define th...
# 20  Erik S. Knutsen's areas of academic interest i...
# 21  Research Interests Issues of democracy and div...
# 22  Kathleen Lahey is Professor and Queen's Nation...
# 23  Nicolas Lamp joined the Faculty of Law at Quee...
# 24  Research Areas Surveillance and Social Sorting...
# 25  Cherie Metcalf is an Associate Professor at Qu...
# 26  Professor Pardy is a classically liberal legal...
# 27  Teaching Subjects Health Law Torts Mental Heal...
# 28  Michael G Pratt is an Associate Professor of L...
# 29  Darryl Robinson was a Hauser Scholar at New Yo...
# 30  Don Stuart was appointed to Queen’s in 1975. P...
# 31  Education BA, University of Toronto MA, Univer...
# 32  Jean Thomas is an Associate Professor at Queen...
# 33  Sabine Tsuruda is an Assistant Professor at Qu...
# 34  Ashwini Vasanthakumar is an Associate Professo...
# 35  Grégoire Webber is Canada Research Chair in Pu...
# 36  Jacob Weinrib is an Associate Professor at the...
# 37  Noah Weisbord is an Associate Professor at Que...
# 38  Robert Yalden is the inaugural holder of the S...
#
#                                 listed_research_areas
# 0   Aboriginal Law; Constitutional Law; Legal & Po...
# 1   Constitutional Law; Immigration Law; Internati...
# 2   Feminist Legal Studies; Intellectual Property;...
# 3      Comparative Law; Family Law; International Law
# 4                      Charter Of Rights And Freedoms
# 5               Children's Law; Contracts; Family Law
# 6       Labour & Employment; Labour Law; Property Law
# 7   Comparative Law; Environmental Law; Feminist L...
# 8                     Labour & Employment; Labour Law
# 9                                                None
# 10  Criminal Law; Criminal Procedure; Legal & Poli...
# 11       Elder Law; Estates; Trusts And Fiduciary Law
# 12         Immigration Law; Legal & Political Thought
# 13  Contracts; Corporate Governance; Corporate Law...
# 14  Human Rights Law; Immigration Law; Internation...
# 15  Arbitration; International Economic Law; Inter...
# 16                                               None
# 17  Criminal Law; Prison Law; Punishment Theory; S...
# 18  Corporate Governance; Corporate Law; Mergers &...
# 19                       Contracts; International Law
# 20  Civil Procedure; Health Law; Insurance Law; Torts
# 21                                               None
# 22  Taxation; Corporate Taxation; Tax Policy; Comp...
# 23         International Law; International Trade Law
# 24                        Law And Technology; Privacy
# 25  Aboriginal Law; Constitutional Law; Environmen...
# 26  Civil Procedure; Constitutional Law; Environme...
# 27                                  Health Law; Torts
# 28  Contracts; Legal & Political Thought; Philosop...
# 29  International Criminal Law; Legal & Political ...
# 30                   Criminal Law; Criminal Procedure
# 31                                               None
# 32  Human Rights Law; Legal & Political Thought; P...
# 33  Contracts; Labour & Employment; Legal & Politi...
# 34  Contracts; Legal & Political Thought; Philosop...
# 35  Charter Of Rights And Freedoms; Constitutional...
# 36  Constitutional Law; Legal & Political Thought;...
# 37  Criminal Law; Evidence; International Criminal...
# 38  Corporate Finance; Corporate Governance; Corpo...

# %% [markdown]
# ### (5) Scrape Western University Faculty Bios

# %%
# get list of faculty and their pages

# Define the base url for the faculty website
base_url = "https://law.uwo.ca/about_us/faculty/"

# Get the html content of the faculty page
response = requests.get(base_url+ '/index.html')
soup = BeautifulSoup(response.content, "html.parser")

# Find all divs that are class 'teamgrid'
profs = soup.find_all('div', {'class': 'teamgrid'})

results = []
for prof in profs:
    result = {}
    result['faculty'] = 'western'
    infoleft = prof.find('div', {'class': 'infoleft'})
    result['name'] = infoleft.find('a').text.strip()
    result['name'] = result['name'].replace('(On Sabbatical Leave)', '').strip()
    result['title'] = infoleft.find('a').next_sibling.strip()
    inforight = prof.find('div', {'class': 'inforight'})
    result['email'] = inforight.find('a').text.strip()
    result['href'] = base_url + infoleft.find('a')['href']
    research_area = infoleft.find('a').find_next_sibling()
    sibling = infoleft.find('a').next_sibling.next_sibling.next_sibling.find_next_sibling()
    if sibling:
        result['listed_research_areas'] = sibling.next_sibling
        result['listed_research_areas'] = result['listed_research_areas'].replace(',', ';').strip()
    else:
        result['listed_research_areas'] = None
    
    results.append(result)

    
# convert to df
df = pd.DataFrame(results)

# drop rows where not research faculty
df = df[~df['title'].str.startswith('Director of Clinics')] # unclear whether tenure stream research faculty
df = df[~df['title'].str.startswith('Assistant Dean')]

df
# Out:
#     faculty                     name  \
# 0   western              Bassem Awad
# 1   western         Andrew Botterell
# 2   western           Colin Campbell
# 3   western              Chi Carmody
# 4   western        Erika Chamberlain
# 5   western            Michael Coyle
# 6   western         Gillian Demeyere
# 7   western          Francesco Ducci
# 8   western         Jennifer Farrell
# 10  western              Rory Gillis
# 11  western            Randal Graham
# 12  western           Claire Houston
# 13  western            Shimelis Kene
# 14  western             Rande Kostal
# 16  western             Nadia Lambek
# 17  western          Joanna Langille
# 18  western                Ryan Liss
# 19  western           Carl MacArthur
# 20  western          Margaret Martin
# 21  western              Alan Miller
# 22  western             Jason Neyers
# 23  western  Christopher C. Nicholls
# 24  western          Alfonso Nocilla
# 25  western       Valerie Oosterveld
# 26  western               Manish Oza
# 27  western            Martin Petrin
# 28  western            Stephen Pitel
# 29  western             Akis Psygkas
# 30  western          Melanie Randall
# 31  western       David Sandomierski
# 32  western            Jacob Shelley
# 33  western      Christopher Sherrin
# 34  western                Zoë Sinel
# 35  western          Elizabeth Steyn
# 36  western            Thomas Telfer
# 37  western            Samuel Trosow
# 38  western          Jeffrey Warnock
# 39  western              Wade Wright
# 40  western                  Andy Yu
#
#                                                 title  \
# 0                                 Assistant Professor
# 1                      Associate Professor (On Leave)
# 2                  Associate Professor (Limited-Term)
# 3                                 Associate Professor
# 4                          Professor, Dean (On Leave)
# 5           Associate Professor (On Sabbatical Leave)
# 6                                 Associate Professor
# 7                                 Assistant Professor
# 8                                 Assistant Professor
# 10                     Assistant Professor (On Leave)
# 11  Professor; Goodmans LLP Faculty Fellow in Lega...
# 12                                Assistant Professor
# 13                 Assistant Professor (Limited-Term)
# 14                                          Professor
# 16                                Assistant Professor
# 17                                Assistant Professor
# 18                                Assistant Professor
# 19                                Assistant Professor
# 20                                Associate Professor
# 21  Associate Professor and Canada Research Chair,...
# 22                    Professor (On Sabbatical Leave)
# 23  Professor, Acting Dean; W. Geoff Beattie Chair...
# 24                                Assistant Professor
# 25                                          Professor
# 26                                Assistant Professor
# 27  Associate Professor, Dancap Private Equity Cha...
# 28                                          Professor
# 29                                Associate Professor
# 30          Associate Professor (On Sabbatical Leave)
# 31                                Assistant Professor
# 32                                Associate Professor
# 33    Associate Professor & Associate Dean (Academic)
# 34  Associate Professor & Associate Dean (Research...
# 35  Assistant Professor; Cassels Brock Fellow in M...
# 36                                          Professor
# 37          Associate Professor (On Sabbatical Leave)
# 38                                Assistant Professor
# 39          Associate Professor (On Sabbatical Leave)
# 40                                Assistant Professor
#
#                         email  \
# 0               bawad4@uwo.ca
# 1     andrew.botterell@uwo.ca
# 2             ccampb64@uwo.ca
# 3             ccarmody@uwo.ca
# 4              echambe@uwo.ca
# 5               mcoyle@uwo.ca
# 6             gdemeyer@uwo.ca
# 7               fducci@uwo.ca
# 8              jfarre9@uwo.ca
# 10         rory.gillis@uwo.ca
# 11              randal@uwo.ca
# 12      claire.houston@uwo.ca
# 13               skene@uwo.ca
# 14                 rwk@uwo.ca
# 16             nlambek@uwo.ca
# 17     joanna.langille@uwo.ca
# 18               rliss@uwo.ca
# 19            cmacart3@uwo.ca
# 20              mmart2@uwo.ca
# 21         alan.miller@uwo.ca
# 22             jneyers@uwo.ca
# 23            cnichol8@uwo.ca
# 24            anocilla@uwo.ca
# 25             vooster@uwo.ca
# 26                moza@uwo.ca
# 27             mpetrin@uwo.ca
# 28              spitel@uwo.ca
# 29            apsygkas@uwo.ca
# 30            randallm@uwo.ca
# 31  david.sandomierski@uwo.ca
# 32       jacob.shelley@uwo.ca
# 33            csherrin@uwo.ca
# 34              zsinel@uwo.ca
# 35             esteyn2@uwo.ca
# 36             ttelfer@uwo.ca
# 37             strosow@uwo.ca
# 38             jwarnoc@uwo.ca
# 39            wwright8@uwo.ca
# 40             andy.yu@uwo.ca
#
#                                                  href  \
# 0   https://law.uwo.ca/about_us/faculty/bassem_awa...
# 1   https://law.uwo.ca/about_us/faculty/andrew_bot...
# 2   https://law.uwo.ca/about_us/faculty/colin_camp...
# 3   https://law.uwo.ca/about_us/faculty/chi_carmod...
# 4   https://law.uwo.ca/about_us/faculty/erika_cham...
# 5   https://law.uwo.ca/about_us/faculty/michael_co...
# 6   https://law.uwo.ca/about_us/faculty/gillian_de...
# 7   https://law.uwo.ca/about_us/faculty/francesco_...
# 8   https://law.uwo.ca/about_us/faculty/jennifer_f...
# 10  https://law.uwo.ca/about_us/faculty/rory_gilli...
# 11  https://law.uwo.ca/about_us/faculty/randal_gra...
# 12  https://law.uwo.ca/about_us/faculty/claire_hou...
# 13  https://law.uwo.ca/about_us/faculty/shimelis_k...
# 14  https://law.uwo.ca/about_us/faculty/rande_kost...
# 16  https://law.uwo.ca/about_us/faculty/nadia_lamb...
# 17  https://law.uwo.ca/about_us/faculty/joanna_lan...
# 18  https://law.uwo.ca/about_us/faculty/ryan_liss....
# 19  https://law.uwo.ca/about_us/faculty/carl_macar...
# 20  https://law.uwo.ca/about_us/faculty/margaret_m...
# 21  https://law.uwo.ca/about_us/faculty/alan_mille...
# 22  https://law.uwo.ca/about_us/faculty/jason_neye...
# 23  https://law.uwo.ca/about_us/faculty/christophe...
# 24  https://law.uwo.ca/about_us/faculty/alfonso_no...
# 25  https://law.uwo.ca/about_us/faculty/valerie_oo...
# 26  https://law.uwo.ca/about_us/faculty/manish_oza...
# 27  https://law.uwo.ca/about_us/faculty/martin_pet...
# 28  https://law.uwo.ca/about_us/faculty/stephen_pi...
# 29  https://law.uwo.ca/about_us/faculty/akis_psygk...
# 30  https://law.uwo.ca/about_us/faculty/melanie_ra...
# 31  https://law.uwo.ca/about_us/faculty/david_sand...
# 32  https://law.uwo.ca/about_us/faculty/jacob_shel...
# 33  https://law.uwo.ca/about_us/faculty/christophe...
# 34  https://law.uwo.ca/about_us/faculty/zoe_sinel....
# 35  https://law.uwo.ca/about_us/faculty/elizabeth_...
# 36  https://law.uwo.ca/about_us/faculty/thomas_tel...
# 37  https://law.uwo.ca/about_us/faculty/sam_trosow...
# 38  https://law.uwo.ca/about_us/faculty/jeffrey_wa...
# 39  https://law.uwo.ca/about_us/faculty/wade_wrigh...
# 40   https://law.uwo.ca/about_us/faculty/andy_yu.html
#
#                                 listed_research_areas
# 0   Law and Technology; Patent Law; Copyright Law;...
# 1        Private Law; Criminal Law; Philosophy of Law
# 2   Income Taxation; International Tax; Corporate Law
# 3   Public International Law; International Trade ...
# 4   Torts; Trusts; Public Authority Liability; Mis...
# 5   Alternative Dispute Resolution; Aboriginal Law...
# 6   Contract Law; Employment Law; Human Rights; Fe...
# 7   Competition / Antitrust Law and Policy; Econom...
# 8   Income Tax; International Tax; International T...
# 10                Tax Law; Tax Policy; and Federalism
# 11  Statutory interpretation; Legislation; Legal E...
# 12  Family Law; Children's Law; and Feminist Legal...
# 13  Public International law; International Human ...
# 14                               Legal History; Torts
# 16  Food Law and Policy; International Law; Human ...
# 17  Private International Law; International Trade...
# 18  Public International Law; Criminal Law; Intern...
# 19  Income Tax Law; Contract Law; Corporate Law an...
# 20  Philosophy of Law; Constitutional Law; Interna...
# 21                   Law and Economics; Corporate Law
# 22  Tort Law; Contract Law; Unjust Enrichment; Pri...
# 23  Corporate Law; Securities Regulation; Corporat...
# 24  Corporate Insolvency; Contracts; and Commercia...
# 25  International criminal law (including sexual a...
# 26          Property; Contract; and Philosophy of Law
# 27                                               None
# 28  Civil Litigation; Courts; Judges; Legal Ethics...
# 29  (Canadian and Comparative) Public Law; Law of ...
# 30  Human Rights; Sex Discrimination; Gendered Vio...
# 31      Contracts; Legal History; and Legal Education
# 32  Public Health Law; Policy & Ethics; Health Law...
# 33  Criminal Law; Criminal Procedure; Evidence; Se...
# 34  Private Law; Torts; Unjust Enrichment; Remedie...
# 35                                               None
# 36  Insolvency Law; Commercial Law; Contracts; Leg...
# 37   Copyright Law; Media Law; Privacy; Municipal Law
# 38                                               None
# 39  Constitutional Law; Federalism; Administrative...
# 40  Jurisprudence; Constitutional Law; Administrat...

# %%
def get_bio(row):
    response = requests.get(row['href'])
    soup = BeautifulSoup(response.text, 'html.parser')
    # get text from class grid_9
    bio = soup.find('div', {'class': 'grid_9'})
    if bio:
        if row['listed_research_areas']:
            bio = bio.text + ' Research areas: ' + row['listed_research_areas']
        else:
            bio = bio.text
        bio = bio.replace('\n', ' ')
        bio = ' '.join(bio.split())
        bio = bio.strip()
        row['bio']=bio
    else:
        row['bio']=None
    
    time.sleep(0.25)

    return row

df = df.apply(get_bio, axis=1)

# Change order of columns
df = df[['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas']]

# Save to json for future use
df.to_json(json_outpath + 'western_bios.json', orient='records', indent = 2)

df
# Out:
#     faculty                     name  \
# 0   western              Bassem Awad
# 1   western         Andrew Botterell
# 2   western           Colin Campbell
# 3   western              Chi Carmody
# 4   western        Erika Chamberlain
# 5   western            Michael Coyle
# 6   western         Gillian Demeyere
# 7   western          Francesco Ducci
# 8   western         Jennifer Farrell
# 10  western              Rory Gillis
# 11  western            Randal Graham
# 12  western           Claire Houston
# 13  western            Shimelis Kene
# 14  western             Rande Kostal
# 16  western             Nadia Lambek
# 17  western          Joanna Langille
# 18  western                Ryan Liss
# 19  western           Carl MacArthur
# 20  western          Margaret Martin
# 21  western              Alan Miller
# 22  western             Jason Neyers
# 23  western  Christopher C. Nicholls
# 24  western          Alfonso Nocilla
# 25  western       Valerie Oosterveld
# 26  western               Manish Oza
# 27  western            Martin Petrin
# 28  western            Stephen Pitel
# 29  western             Akis Psygkas
# 30  western          Melanie Randall
# 31  western       David Sandomierski
# 32  western            Jacob Shelley
# 33  western      Christopher Sherrin
# 34  western                Zoë Sinel
# 35  western          Elizabeth Steyn
# 36  western            Thomas Telfer
# 37  western            Samuel Trosow
# 38  western          Jeffrey Warnock
# 39  western              Wade Wright
# 40  western                  Andy Yu
#
#                                                 title  \
# 0                                 Assistant Professor
# 1                      Associate Professor (On Leave)
# 2                  Associate Professor (Limited-Term)
# 3                                 Associate Professor
# 4                          Professor, Dean (On Leave)
# 5           Associate Professor (On Sabbatical Leave)
# 6                                 Associate Professor
# 7                                 Assistant Professor
# 8                                 Assistant Professor
# 10                     Assistant Professor (On Leave)
# 11  Professor; Goodmans LLP Faculty Fellow in Lega...
# 12                                Assistant Professor
# 13                 Assistant Professor (Limited-Term)
# 14                                          Professor
# 16                                Assistant Professor
# 17                                Assistant Professor
# 18                                Assistant Professor
# 19                                Assistant Professor
# 20                                Associate Professor
# 21  Associate Professor and Canada Research Chair,...
# 22                    Professor (On Sabbatical Leave)
# 23  Professor, Acting Dean; W. Geoff Beattie Chair...
# 24                                Assistant Professor
# 25                                          Professor
# 26                                Assistant Professor
# 27  Associate Professor, Dancap Private Equity Cha...
# 28                                          Professor
# 29                                Associate Professor
# 30          Associate Professor (On Sabbatical Leave)
# 31                                Assistant Professor
# 32                                Associate Professor
# 33    Associate Professor & Associate Dean (Academic)
# 34  Associate Professor & Associate Dean (Research...
# 35  Assistant Professor; Cassels Brock Fellow in M...
# 36                                          Professor
# 37          Associate Professor (On Sabbatical Leave)
# 38                                Assistant Professor
# 39          Associate Professor (On Sabbatical Leave)
# 40                                Assistant Professor
#
#                         email  \
# 0               bawad4@uwo.ca
# 1     andrew.botterell@uwo.ca
# 2             ccampb64@uwo.ca
# 3             ccarmody@uwo.ca
# 4              echambe@uwo.ca
# 5               mcoyle@uwo.ca
# 6             gdemeyer@uwo.ca
# 7               fducci@uwo.ca
# 8              jfarre9@uwo.ca
# 10         rory.gillis@uwo.ca
# 11              randal@uwo.ca
# 12      claire.houston@uwo.ca
# 13               skene@uwo.ca
# 14                 rwk@uwo.ca
# 16             nlambek@uwo.ca
# 17     joanna.langille@uwo.ca
# 18               rliss@uwo.ca
# 19            cmacart3@uwo.ca
# 20              mmart2@uwo.ca
# 21         alan.miller@uwo.ca
# 22             jneyers@uwo.ca
# 23            cnichol8@uwo.ca
# 24            anocilla@uwo.ca
# 25             vooster@uwo.ca
# 26                moza@uwo.ca
# 27             mpetrin@uwo.ca
# 28              spitel@uwo.ca
# 29            apsygkas@uwo.ca
# 30            randallm@uwo.ca
# 31  david.sandomierski@uwo.ca
# 32       jacob.shelley@uwo.ca
# 33            csherrin@uwo.ca
# 34              zsinel@uwo.ca
# 35             esteyn2@uwo.ca
# 36             ttelfer@uwo.ca
# 37             strosow@uwo.ca
# 38             jwarnoc@uwo.ca
# 39            wwright8@uwo.ca
# 40             andy.yu@uwo.ca
#
#                                                  href  \
# 0   https://law.uwo.ca/about_us/faculty/bassem_awa...
# 1   https://law.uwo.ca/about_us/faculty/andrew_bot...
# 2   https://law.uwo.ca/about_us/faculty/colin_camp...
# 3   https://law.uwo.ca/about_us/faculty/chi_carmod...
# 4   https://law.uwo.ca/about_us/faculty/erika_cham...
# 5   https://law.uwo.ca/about_us/faculty/michael_co...
# 6   https://law.uwo.ca/about_us/faculty/gillian_de...
# 7   https://law.uwo.ca/about_us/faculty/francesco_...
# 8   https://law.uwo.ca/about_us/faculty/jennifer_f...
# 10  https://law.uwo.ca/about_us/faculty/rory_gilli...
# 11  https://law.uwo.ca/about_us/faculty/randal_gra...
# 12  https://law.uwo.ca/about_us/faculty/claire_hou...
# 13  https://law.uwo.ca/about_us/faculty/shimelis_k...
# 14  https://law.uwo.ca/about_us/faculty/rande_kost...
# 16  https://law.uwo.ca/about_us/faculty/nadia_lamb...
# 17  https://law.uwo.ca/about_us/faculty/joanna_lan...
# 18  https://law.uwo.ca/about_us/faculty/ryan_liss....
# 19  https://law.uwo.ca/about_us/faculty/carl_macar...
# 20  https://law.uwo.ca/about_us/faculty/margaret_m...
# 21  https://law.uwo.ca/about_us/faculty/alan_mille...
# 22  https://law.uwo.ca/about_us/faculty/jason_neye...
# 23  https://law.uwo.ca/about_us/faculty/christophe...
# 24  https://law.uwo.ca/about_us/faculty/alfonso_no...
# 25  https://law.uwo.ca/about_us/faculty/valerie_oo...
# 26  https://law.uwo.ca/about_us/faculty/manish_oza...
# 27  https://law.uwo.ca/about_us/faculty/martin_pet...
# 28  https://law.uwo.ca/about_us/faculty/stephen_pi...
# 29  https://law.uwo.ca/about_us/faculty/akis_psygk...
# 30  https://law.uwo.ca/about_us/faculty/melanie_ra...
# 31  https://law.uwo.ca/about_us/faculty/david_sand...
# 32  https://law.uwo.ca/about_us/faculty/jacob_shel...
# 33  https://law.uwo.ca/about_us/faculty/christophe...
# 34  https://law.uwo.ca/about_us/faculty/zoe_sinel....
# 35  https://law.uwo.ca/about_us/faculty/elizabeth_...
# 36  https://law.uwo.ca/about_us/faculty/thomas_tel...
# 37  https://law.uwo.ca/about_us/faculty/sam_trosow...
# 38  https://law.uwo.ca/about_us/faculty/jeffrey_wa...
# 39  https://law.uwo.ca/about_us/faculty/wade_wrigh...
# 40   https://law.uwo.ca/about_us/faculty/andy_yu.html
#
#                                                   bio  \
# 0   Bassem Awad Academic Degrees: PhD (University ...
# 1   Andrew Botterell Academic Degrees: B.A.(Hons.)...
# 2   Colin Campbell Academic Degrees: B.A. (Univers...
# 3   Chi Carmody Academic Degrees: LL.B. (Ottawa), ...
# 4   Erika Chamberlain Academic Degrees: LLB (Dist)...
# 5   Michael Coyle Academic Degrees: LLB (Western U...
# 6   Gillian Demeyere Academic Degrees: B.A. (Weste...
# 7   Francesco Ducci Academic Degrees: SJD and LLM ...
# 8   Jennifer Farrell Email: jfarre9@uwo.ca Phone: ...
# 10  Rory Gillis Academic Degrees: BA (Yale); JD (Y...
# 11  Randal Graham Academic Degrees: Goodmans LLP F...
# 12  Claire Houston Academic Degrees: B.A. (Hons.) ...
# 13  Shimelis Kene Academic Degrees: LL.B (Addis Ab...
# 14  Rande Kostal Academic Degrees: LL.B. (Western ...
# 16  Nadia Lambek Academic Degrees: BA (Brown Unive...
# 17  Joanna Langille Academic Degrees: Hons BA (Tor...
# 18  Ryan Liss Academic Degrees: Hons. B.A. (Toront...
# 19  Carl MacArthur Academic Degrees: B.A. (Hons) (...
# 20  Margaret Martin Academic Degrees: B.A. (Hons) ...
# 21  Alan Miller Academic Degrees: B.A. 1998, Unive...
# 22  Jason Neyers Academic Degrees: B.A. (Hon.) (We...
# 23  Christopher Nicholls Academic Degrees: B.A. (H...
# 24  Alfonso Nocilla Academic Degrees: B.A. (Philos...
# 25  Valerie Oosterveld Academic Degrees: B.Soc.Sc....
# 26  Manish Oza Academic Degrees: BA (hons) (Oxford...
# 27  Martin Petrin Academic Degrees: S.J.D., Univer...
# 28  Stephen Pitel Academic Degrees: BA (Carleton) ...
# 29  Athanasios (Akis) Psygkas Academic Degrees: J....
# 30  Melanie RandallB.A. (University of Toronto), M...
# 31  David Sandomierski Academic Degrees: B.A.Sc. (...
# 32  Jacob Shelley Academic Degrees: SJD (Universit...
# 33  Christopher Sherrin Academic Degrees: Doctor o...
# 34  Zoë Sinel Academic Degrees: SJD (University of...
# 35  Elizabeth Steyn Academic Degrees: LL.D. (Unive...
# 36  Thomas Telfer Academic Degrees: BA (Hons) (Wes...
# 37  Sam Trosow Academic Degrees: BA (Pennsylvania ...
# 38  Jeffrey Warnock Academic Degrees: Hons. B.A. (...
# 39  Wade Wright Academic Degrees: Hons. B. Mus. (W...
# 40  Andy Yu Academic Degrees: BA (McGill), BPhil (...
#
#                                 listed_research_areas
# 0   Law and Technology; Patent Law; Copyright Law;...
# 1        Private Law; Criminal Law; Philosophy of Law
# 2   Income Taxation; International Tax; Corporate Law
# 3   Public International Law; International Trade ...
# 4   Torts; Trusts; Public Authority Liability; Mis...
# 5   Alternative Dispute Resolution; Aboriginal Law...
# 6   Contract Law; Employment Law; Human Rights; Fe...
# 7   Competition / Antitrust Law and Policy; Econom...
# 8   Income Tax; International Tax; International T...
# 10                Tax Law; Tax Policy; and Federalism
# 11  Statutory interpretation; Legislation; Legal E...
# 12  Family Law; Children's Law; and Feminist Legal...
# 13  Public International law; International Human ...
# 14                               Legal History; Torts
# 16  Food Law and Policy; International Law; Human ...
# 17  Private International Law; International Trade...
# 18  Public International Law; Criminal Law; Intern...
# 19  Income Tax Law; Contract Law; Corporate Law an...
# 20  Philosophy of Law; Constitutional Law; Interna...
# 21                   Law and Economics; Corporate Law
# 22  Tort Law; Contract Law; Unjust Enrichment; Pri...
# 23  Corporate Law; Securities Regulation; Corporat...
# 24  Corporate Insolvency; Contracts; and Commercia...
# 25  International criminal law (including sexual a...
# 26          Property; Contract; and Philosophy of Law
# 27                                               None
# 28  Civil Litigation; Courts; Judges; Legal Ethics...
# 29  (Canadian and Comparative) Public Law; Law of ...
# 30  Human Rights; Sex Discrimination; Gendered Vio...
# 31      Contracts; Legal History; and Legal Education
# 32  Public Health Law; Policy & Ethics; Health Law...
# 33  Criminal Law; Criminal Procedure; Evidence; Se...
# 34  Private Law; Torts; Unjust Enrichment; Remedie...
# 35                                               None
# 36  Insolvency Law; Commercial Law; Contracts; Leg...
# 37   Copyright Law; Media Law; Privacy; Municipal Law
# 38                                               None
# 39  Constitutional Law; Federalism; Administrative...
# 40  Jurisprudence; Constitutional Law; Administrat...

# %% [markdown]
# ### (6) Scrape U Windsor Faculty Bios

# %%
base_url = 'https://www.uwindsor.ca/law/382/full-time-faculty'

response = requests.get(base_url)
soup = BeautifulSoup(response.text, 'html.parser')

# get all div class 'btgrid'
initial_profs = soup.find_all('div', {'class': 'btgrid'})
initial_profs = initial_profs[1:] # remove first

# stop when get to Professors Emeriti
profs = []
for prof in initial_profs:
    if 'Professors Emeriti' in prof.text:
        break
    else:
        profs.append(prof)

results = []
for prof in profs:
    result = {}

    result['faculty'] = 'windsor'
    
    result['name'] = prof.find('a').text     
    
    result['title'] = prof.find('div', {'class': 'col col-md-10'}).find('p').text
    result['title'] = result['title'].split('\n')[0]
    result['title'] = result['title'].replace(u'\xa0', u' ')

    hrefs = prof.find_all('a')
    if len(hrefs) > 1:
        result['email'] = hrefs[1].text
    else:
        result['email'] = None
    
    result['href'] = prof.find('a')['href']

    # Correct errors where no faculty bio link
    if '@' in result['name']:
        result['email']=result['name']
        result['href']=None
        # get first line of text from fist h3
        result['name'] = prof.find('h3').text
    
    results.append(result)    

df = pd.DataFrame(results)
df
# Out:
#     faculty                      name  \
# 0   windsor               Paul Ocheje
# 1   windsor            Chris Fredette
# 2   windsor               Wissam Aoun
# 3   windsor             Jeff Berryman
# 4   windsor               Irina Ceric
# 5   windsor       Pascale Chapdelaine
# 6   windsor  Patricia Galvão Ferreira
# 7   windsor            Beverly Jacobs
# 8   windsor            Laverne Jacobs
# 9   windsor             Danardo Jones
# 10  windsor        Jasminka Kalajdzic
# 11  windsor          Muharem Kianieff
# 12  windsor                Ruth Kuras
# 13  windsor           Margaret Liddle
# 14  windsor             Sylvia Mcadam
# 15  windsor              Richard Moon
# 16  windsor              Claire Mummé
# 17  windsor            Joanna Noronha
# 18  windsor             Jillian Rogin
# 19  windsor               Noel Semple
# 20  windsor  Shanthi Elizabeth Senthe
# 21  windsor              Tess Sheldon
# 22  windsor               Anneke Smit
# 23  windsor               Gemma Smyth
# 24  windsor            David Tanovich
# 25  windsor               Myra Tawfik
# 26  windsor             Lisa Trabucco
# 27  windsor     Mary Anne Vallianatos
# 28  windsor        Vasanthi Venkatesh
# 29  windsor           Valarie Waboose
# 30  windsor        Christopher Waters
# 31  windsor              Sara Wharton
# 32  windsor              Vincent Wong
# 33  windsor             Sujith Xavier
#
#                                              title  \
# 0   Associate Dean (Research and Graduate Studies)
# 1                        Associate Dean (Academic)
# 2                              Assistant Professor
# 3               Distinguished University Professor
# 4                              Assistant Professor
# 5                              Associate Professor
# 6                              Assistant Professor
# 7    Currently on secondment to President's Office
# 8                                        Professor
# 9                              Assistant Professor
# 10                             Associate Professor
# 11                             Associate Professor
# 12                             Assistant Professor
# 13                             Assistant Professor
# 14                             Assistant Professor
# 15              Distinguished University Professor
# 16                             Associate Professor
# 17                             Assistant Professor
# 18                             Assistant Professor
# 19                             Associate Professor
# 20                             Assistant Professor
# 21                             Assistant Professor
# 22                             Associate Professor
# 23                             Associate Professor
# 24                                       Professor
# 25              Distinguished University Professor
# 26                             Assistant Professor
# 27                             Assistant Professor
# 28                             Associate Professor
# 29                             Assistant Professor
# 30                                       Professor
# 31                             Associate Professor
# 32                             Assistant Professor
# 33                             Associate Professor
#
#                              email  \
# 0              pocheje@uwindsor.ca
# 1             fredette@uwindsor.ca
# 2                waoun@uwindsor.ca
# 3              jberrym@uwindsor.ca
# 4          Irina.Ceric@uwindsor.ca
# 5              chapdel@uwindsor.ca
# 6      Patricia.Galvao@uwindsor.ca
# 7       beverly.jacobs@uwindsor.ca
# 8              ljacobs@uwindsor.ca
# 9        Danardo.Jones@uwindsor.ca
# 10              kalajj@uwindsor.ca
# 11            kianieff@uwindsor.ca
# 12              rkuras@uwindsor.ca
# 13              maggie@uwindsor.ca
# 14       Sylvia.Mcadam@uwindsor.ca
# 15               rmoon@uwindsor.ca
# 16              cmumme@uwindsor.ca
# 17     Joanna.vnoronha@uwindsor.ca
# 18       Jillian.Rogin@uwindsor.ca
# 19         Noel.Semple@uwindsor.ca
# 20            s.senthe@uwindsor.ca
# 21        tess.sheldon@uwindsor.ca
# 22               asmit@uwindsor.ca
# 23         gemma.smyth@uwindsor.ca
# 24            tanovich@uwindsor.ca
# 25                 mjt@uwindsor.ca
# 26       Lisa.Trabucco@uwindsor.ca
# 27         Vallianatos@uwindsor.ca
# 28  vasanthi.venkatesh@uwindsor.ca
# 29     valarie.waboose@uwindsor.ca
# 30             cwaters@uwindsor.ca
# 31            swharton@uwindsor.ca
# 32        vincent.wong@uwindsor.ca
# 33             sxavier@uwindsor.ca
#
#                                                  href
# 0                 http://www.uwindsor.ca/law/pocheje/
# 1   https://www.uwindsor.ca/business/430/chris-fre...
# 2             https://www.uwindsor.ca/law/Wissam-Aoun
# 3                http://www.uwindsor.ca/law/berryman/
# 4   https://www.uwindsor.ca/law/3049/irina-ceric-a...
# 5                 http://www.uwindsor.ca/law/chapdel/
# 6   https://www.uwindsor.ca/law/Patr%C3%ADcia-Galv...
# 7          https://www.uwindsor.ca/law/Beverly-Jacobs
# 8                 http://www.uwindsor.ca/law/ljacobs/
# 9           https://www.uwindsor.ca/law/Danardo-Jones
# 10                 http://www.uwindsor.ca/law/kalajj/
# 11       https://www.uwindsor.ca/law/Muharem-Kianieff
# 12                                               None
# 13                                               None
# 14                                               None
# 15                  http://www.uwindsor.ca/law/rmoon/
# 16                 http://www.uwindsor.ca/law/cmumme/
# 17                                               None
# 18     https://www.uwindsor.ca/law/1630/jillian-rogin
# 19                http://www.uwindsor.ca/law/nsemple/
# 20  https://www.uwindsor.ca/law/1372/shanthi-eliza...
# 21           https://www.uwindsor.ca/law/Tess-Sheldon
# 22                  http://www.uwindsor.ca/law/asmit/
# 23               https://www.uwindsor.ca/law/gesmyth/
# 24               http://www.uwindsor.ca/law/tanovich/
# 25                 http://www.uwindsor.ca/law/tawfik/
# 26                                               None
# 27  https://www.uwindsor.ca/law/3090/mary-anne-val...
# 28  https://www.uwindsor.ca/law/983/vasanthi-venka...
# 29    https://www.uwindsor.ca/law/945/valarie-waboose
# 30                http://www.uwindsor.ca/law/cwaters/
# 31              https://www.uwindsor.ca/law/swharton/
# 32  https://www.uwindsor.ca/law/3050/vincent-wong-...
# 33                http://www.uwindsor.ca/law/sxavier/

# %%
### Add faculty bios

def get_bio(row):
    if not row['href']:
        row['bio'] = None
        return row
    
    response = requests.get(row['href'])
    soup = BeautifulSoup(response.text, 'html.parser')

    # try to get bio
    bio = soup.find('div', {'id': 'block-system-main'})
    if bio:
        bio = bio.text
        bio = bio.replace('\n', ' ').strip()
    else:
        bio = soup.find('div', {'class': 'region region-content'})
        bio = bio.text
        bio = bio.replace('\n', ' ').strip()
    if bio:
        row['bio']=bio
    else:
        row['bio']=None
    
    # try to get listed_research_areas
    sidebar = soup.find('div', {'class': 'region region-sidebar-second'})
    if sidebar:
        sidebar = sidebar.text
        if 'Expertise' in sidebar:
            sidebar = sidebar.split('Expertise')[1]
            sidebar = sidebar.split('..')[0]
            sidebar = sidebar.strip()
            sidebar = sidebar.replace('\n', '; ').strip()
            sidebar = sidebar.title()
            
            row['listed_research_areas'] = sidebar
            row['bio'] = bio + ' Research areas: ' + sidebar
        else:
            row['listed_research_areas'] = None
    else:
        row['listed_research_areas'] = None

    return row

df = df.apply(get_bio, axis=1)

# Change order of columns
df = df[['faculty', 'name', 'title', 'email', 'href', 'bio', 'listed_research_areas']]

# Save to json for future use
df.to_json(json_outpath + 'windsor_bios.json', orient='records', indent = 2)

df
# Out:
#     faculty                      name  \
# 0   windsor               Paul Ocheje
# 1   windsor            Chris Fredette
# 2   windsor               Wissam Aoun
# 3   windsor             Jeff Berryman
# 4   windsor               Irina Ceric
# 5   windsor       Pascale Chapdelaine
# 6   windsor  Patricia Galvão Ferreira
# 7   windsor            Beverly Jacobs
# 8   windsor            Laverne Jacobs
# 9   windsor             Danardo Jones
# 10  windsor        Jasminka Kalajdzic
# 11  windsor          Muharem Kianieff
# 12  windsor                Ruth Kuras
# 13  windsor           Margaret Liddle
# 14  windsor             Sylvia Mcadam
# 15  windsor              Richard Moon
# 16  windsor              Claire Mummé
# 17  windsor            Joanna Noronha
# 18  windsor             Jillian Rogin
# 19  windsor               Noel Semple
# 20  windsor  Shanthi Elizabeth Senthe
# 21  windsor              Tess Sheldon
# 22  windsor               Anneke Smit
# 23  windsor               Gemma Smyth
# 24  windsor            David Tanovich
# 25  windsor               Myra Tawfik
# 26  windsor             Lisa Trabucco
# 27  windsor     Mary Anne Vallianatos
# 28  windsor        Vasanthi Venkatesh
# 29  windsor           Valarie Waboose
# 30  windsor        Christopher Waters
# 31  windsor              Sara Wharton
# 32  windsor              Vincent Wong
# 33  windsor             Sujith Xavier
#
#                                              title  \
# 0   Associate Dean (Research and Graduate Studies)
# 1                        Associate Dean (Academic)
# 2                              Assistant Professor
# 3               Distinguished University Professor
# 4                              Assistant Professor
# 5                              Associate Professor
# 6                              Assistant Professor
# 7    Currently on secondment to President's Office
# 8                                        Professor
# 9                              Assistant Professor
# 10                             Associate Professor
# 11                             Associate Professor
# 12                             Assistant Professor
# 13                             Assistant Professor
# 14                             Assistant Professor
# 15              Distinguished University Professor
# 16                             Associate Professor
# 17                             Assistant Professor
# 18                             Assistant Professor
# 19                             Associate Professor
# 20                             Assistant Professor
# 21                             Assistant Professor
# 22                             Associate Professor
# 23                             Associate Professor
# 24                                       Professor
# 25              Distinguished University Professor
# 26                             Assistant Professor
# 27                             Assistant Professor
# 28                             Associate Professor
# 29                             Assistant Professor
# 30                                       Professor
# 31                             Associate Professor
# 32                             Assistant Professor
# 33                             Associate Professor
#
#                              email  \
# 0              pocheje@uwindsor.ca
# 1             fredette@uwindsor.ca
# 2                waoun@uwindsor.ca
# 3              jberrym@uwindsor.ca
# 4          Irina.Ceric@uwindsor.ca
# 5              chapdel@uwindsor.ca
# 6      Patricia.Galvao@uwindsor.ca
# 7       beverly.jacobs@uwindsor.ca
# 8              ljacobs@uwindsor.ca
# 9        Danardo.Jones@uwindsor.ca
# 10              kalajj@uwindsor.ca
# 11            kianieff@uwindsor.ca
# 12              rkuras@uwindsor.ca
# 13              maggie@uwindsor.ca
# 14       Sylvia.Mcadam@uwindsor.ca
# 15               rmoon@uwindsor.ca
# 16              cmumme@uwindsor.ca
# 17     Joanna.vnoronha@uwindsor.ca
# 18       Jillian.Rogin@uwindsor.ca
# 19         Noel.Semple@uwindsor.ca
# 20            s.senthe@uwindsor.ca
# 21        tess.sheldon@uwindsor.ca
# 22               asmit@uwindsor.ca
# 23         gemma.smyth@uwindsor.ca
# 24            tanovich@uwindsor.ca
# 25                 mjt@uwindsor.ca
# 26       Lisa.Trabucco@uwindsor.ca
# 27         Vallianatos@uwindsor.ca
# 28  vasanthi.venkatesh@uwindsor.ca
# 29     valarie.waboose@uwindsor.ca
# 30             cwaters@uwindsor.ca
# 31            swharton@uwindsor.ca
# 32        vincent.wong@uwindsor.ca
# 33             sxavier@uwindsor.ca
#
#                                                  href  \
# 0                 http://www.uwindsor.ca/law/pocheje/
# 1   https://www.uwindsor.ca/business/430/chris-fre...
# 2             https://www.uwindsor.ca/law/Wissam-Aoun
# 3                http://www.uwindsor.ca/law/berryman/
# 4   https://www.uwindsor.ca/law/3049/irina-ceric-a...
# 5                 http://www.uwindsor.ca/law/chapdel/
# 6   https://www.uwindsor.ca/law/Patr%C3%ADcia-Galv...
# 7          https://www.uwindsor.ca/law/Beverly-Jacobs
# 8                 http://www.uwindsor.ca/law/ljacobs/
# 9           https://www.uwindsor.ca/law/Danardo-Jones
# 10                 http://www.uwindsor.ca/law/kalajj/
# 11       https://www.uwindsor.ca/law/Muharem-Kianieff
# 12                                               None
# 13                                               None
# 14                                               None
# 15                  http://www.uwindsor.ca/law/rmoon/
# 16                 http://www.uwindsor.ca/law/cmumme/
# 17                                               None
# 18     https://www.uwindsor.ca/law/1630/jillian-rogin
# 19                http://www.uwindsor.ca/law/nsemple/
# 20  https://www.uwindsor.ca/law/1372/shanthi-eliza...
# 21           https://www.uwindsor.ca/law/Tess-Sheldon
# 22                  http://www.uwindsor.ca/law/asmit/
# 23               https://www.uwindsor.ca/law/gesmyth/
# 24               http://www.uwindsor.ca/law/tanovich/
# 25                 http://www.uwindsor.ca/law/tawfik/
# 26                                               None
# 27  https://www.uwindsor.ca/law/3090/mary-anne-val...
# 28  https://www.uwindsor.ca/law/983/vasanthi-venka...
# 29    https://www.uwindsor.ca/law/945/valarie-waboose
# 30                http://www.uwindsor.ca/law/cwaters/
# 31              https://www.uwindsor.ca/law/swharton/
# 32  https://www.uwindsor.ca/law/3050/vincent-wong-...
# 33                http://www.uwindsor.ca/law/sxavier/
#
#                                                   bio  \
# 0   Professor Paul D. Ocheje joined the Faculty in...
# 1   Chris Fredette, Ph.D. Associate Dean Academic,...
# 2   Wissam Aoun joined the Faculty of Law in July ...
# 3   Jeff Berryman is a Distinguished University Pr...
# 4   Irina Ceric (she/her) joined the Faculty of La...
# 5   Pascale Chapdelaine is Associate Professor at ...
# 6   Patrícia Galvão Ferreira joined the Faculty of...
# 7   Dr. Beverly Jacobs is the Senior Advisor to th...
# 8   Laverne Jacobs, PhD Full Professor  Laverne Ja...
# 9   Danardo Jones joined the Faculty of Law as an ...
# 10  Biography Jasminka Kalajdzic is an Associate P...
# 11  Muharem Kianieff has been a member of the Univ...
# 12                                               None
# 13                                               None
# 14                                               None
# 15  Richard Moon is Distinguished University Profe...
# 16  Claire Mummé joined the University of Windsor ...
# 17                                               None
# 18  Biography Jillian Rogin joined the Faculty of ...
# 19  Noel Semple is an Associate Professor at the U...
# 20  Shanthi Elizabeth Senthe is an Assistant Profe...
# 21  Tess Sheldon joined the University of Windsor ...
# 22  Director, Windsor Law Centre for Cities Associ...
# 23  Associate Professor & Externship Director Prof...
# 24  David M Tanovich is a Professor at the Faculty...
# 25  Don Rodzik Family Chair in Law and Entrepreneu...
# 26                                               None
# 27  Mary Anne Vallianatos joined the Faculty of La...
# 28  Associate Professor- Law, Land, and Local Econ...
# 29  Valarie Waboose graduated from Windsor Law in ...
# 30  Biography  Christopher Waters was Dean of the ...
# 31  Associate Professor Biography Sara Wharton joi...
# 32  Vincent Wong joined the University of Windsor ...
# 33  Biography Dr. Sujith Xavier (Barrister and Sol...
#
#                                 listed_research_areas
# 0   International Development Law; Public Internat...
# 1                                                None
# 2   Intellectual Property Law; Patent Law ; Profes...
# 3                                                None
# 4   Law And Social Movements; Access To Justice; M...
# 5      Contracts; Intellectual Property; Consumer Law
# 6   Law And Society; Transnational Climate Law; Cl...
# 7   Indigenous Legal Orders; Indigenous Wholistic ...
# 8   Administrative Law; Disability Rights; Socio-L...
# 9   Criminal Law; Criminal Procedure; Criminal Sen...
# 10  Access To Justice; Class Actions; Evidence; On...
# 11  Blockchain/Distributed Ledger Technology; Fina...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Freedom Of Religion; Freedom Of Expression; Th...
# 16  Access To Justice; Contract Law; Law Of Work A...
# 17                                                NaN
# 18                                               None
# 19                                               None
# 20                                               None
# 21  ​Access To Justice; Disability Law; Human Righ...
# 22                                               None
# 23  Dispute Resolution; Lawyering Skills; Legal Ed...
# 24  Criminal Law;       Evidence;       Racial Pro...
# 25                                               None
# 26                                                NaN
# 27  Canadian Legal History ; Law And Race  ; Asian...
# 28  Citizenship And Immigration; Law, Radical Resi...
# 29                                               None
# 30  Public International Law; International Humani...
# 31  International Criminal Law; Transnational Crim...
# 32  Racial Capitalism And The Law; Critical Race S...
# 33  Twail & Race And The Law; Administrative Law &...

# %% [markdown]
# ### (7) Scrape Bora Laskin Faculty of Law (Lakehead)

# %%
base_url = 'https://www.lakeheadu.ca'

response = requests.get(base_url + '/programs/departments/law/faculty')
soup = BeautifulSoup(response.text, 'html.parser')

# get all div class 'staff-listing'
profs = soup.find_all('div', {'class': 'staff-listing'})

results = []
for prof in profs:
    result = {}
    result['faculty'] = 'lakehead'
    first_name = prof.find('h2')
    last_name = first_name.next_sibling.next_sibling
    result['name'] = first_name.text.strip() + ' ' + last_name.text.strip()
    result['name'] = result['name'].replace('Dr. ', '').replace('Prof. ', '')
    result['title'] = prof.find('h3').text.strip()
    result['email'] = re.findall(r'[\w\.-]+@[\w\.-]+', prof.text)[0]
    # get link with the text that starts with "Read more"
    result['href'] = base_url + prof.find('a', text=re.compile('^Read more'))['href']
    

    results.append(result)

# create df
df = pd.DataFrame(results)
df
# Out:
#      faculty                name                title  \
# 0   lakehead         Ryan Alford            Professor
# 1   lakehead          Joan Braun  Assistant Professor
# 2   lakehead    Mariette Brennan  Associate Professor
# 3   lakehead    Tenille E. Brown  Assistant Professor
# 4   lakehead  Frances E. Chapman            Professor
# 5   lakehead        Daniel Dylan  Associate Professor
# 6   lakehead   Martin-Joe Ezeudu  Assistant Professor
# 7   lakehead         Jula Hughes      Dean, Professor
# 8   lakehead           Phil Lord  Assistant Professor
# 9   lakehead        Wendy Parkes  Assistant Professor
# 10  lakehead     David Rosenberg  Assistant Professor
# 11  lakehead          Semie Sama  Assistant Professor
# 12  lakehead       Larissa Speak  Assistant Professor
# 13  lakehead     Robin Whitehead  Assistant Professor
#
#                            email  \
# 0           ralford@lakeheadu.ca
# 1           jbraun2@lakeheadu.ca
# 2          mbrennan@lakeheadu.ca
# 3     tenille.brown@lakeheadu.ca
# 4          fchapman@lakeheadu.ca
# 5           dwdylan@lakeheadu.ca
# 6           mezeudu@lakeheadu.ca
# 7          jhughe11@lakeheadu.ca
# 8             plord@lakeheadu.ca
# 9           wparkes@lakeheadu.ca
# 10         drosenbe@lakeheadu.ca
# 11            ssama@lakeheadu.ca
# 12           lspeak@lakeheadu.ca
# 13  robin.whitehead@lakeheadu.ca
#
#                                                  href
# 0   https://www.lakeheadu.ca/users/A/ralford/node/...
# 1   https://www.lakeheadu.ca/users/B/jbraun2/node/...
# 2   https://www.lakeheadu.ca/users/B/mbrennan/node...
# 3   https://www.lakeheadu.ca/users/B/tbrown5/node/...
# 4   https://www.lakeheadu.ca/users/C/fchapman/node...
# 5   https://www.lakeheadu.ca/users/D/dwdylan/node/...
# 6   https://www.lakeheadu.ca/users/E/mezeudu/node/...
# 7   https://www.lakeheadu.ca/users/H/jhughe11/node...
# 8   https://www.lakeheadu.ca/users/L/plord/node/66558
# 9   https://www.lakeheadu.ca/users/P/wparkes/node/...
# 10  https://www.lakeheadu.ca/users/R/drosenbe/node...
# 11  https://www.lakeheadu.ca/users/S/ssama/node/57002
# 12  https://www.lakeheadu.ca/users/S/lspeak/node/7...
# 13  https://www.lakeheadu.ca/users/W/rwhitehe/node...

# %%
# get bios from each href
def get_bio(row):
    response = requests.get(row['href'])
    soup = BeautifulSoup(response.text, 'html.parser')
    bio = soup.find('div', {'class': 'region region-content'}).text
    bio = bio.replace('\n', ' ').strip()
    bio = bio.replace(u'\xa0', u' ')
    bio = ' '.join(bio.split()).strip()
    if 'Academic Qualifications' in bio:
        bio = 'Academic Qualifications: '+ bio.split('Academic Qualifications:')[1]
    
    row['bio'] = bio
    row['listed_research_areas'] = None
    # NOTE: Some of the bios do have research areas listed, but they are mostly in narrative
    # rather than keyword form. Need to use NLP to extract.

    return row

df = df.apply(get_bio, axis=1)

# save to json
df.to_json(json_outpath + 'lakehead_bios.json', orient='records', indent = 2)
df
# Out:
#      faculty                name                title  \
# 0   lakehead         Ryan Alford            Professor
# 1   lakehead          Joan Braun  Assistant Professor
# 2   lakehead    Mariette Brennan  Associate Professor
# 3   lakehead    Tenille E. Brown  Assistant Professor
# 4   lakehead  Frances E. Chapman            Professor
# 5   lakehead        Daniel Dylan  Associate Professor
# 6   lakehead   Martin-Joe Ezeudu  Assistant Professor
# 7   lakehead         Jula Hughes      Dean, Professor
# 8   lakehead           Phil Lord  Assistant Professor
# 9   lakehead        Wendy Parkes  Assistant Professor
# 10  lakehead     David Rosenberg  Assistant Professor
# 11  lakehead          Semie Sama  Assistant Professor
# 12  lakehead       Larissa Speak  Assistant Professor
# 13  lakehead     Robin Whitehead  Assistant Professor
#
#                            email  \
# 0           ralford@lakeheadu.ca
# 1           jbraun2@lakeheadu.ca
# 2          mbrennan@lakeheadu.ca
# 3     tenille.brown@lakeheadu.ca
# 4          fchapman@lakeheadu.ca
# 5           dwdylan@lakeheadu.ca
# 6           mezeudu@lakeheadu.ca
# 7          jhughe11@lakeheadu.ca
# 8             plord@lakeheadu.ca
# 9           wparkes@lakeheadu.ca
# 10         drosenbe@lakeheadu.ca
# 11            ssama@lakeheadu.ca
# 12           lspeak@lakeheadu.ca
# 13  robin.whitehead@lakeheadu.ca
#
#                                                  href  \
# 0   https://www.lakeheadu.ca/users/A/ralford/node/...
# 1   https://www.lakeheadu.ca/users/B/jbraun2/node/...
# 2   https://www.lakeheadu.ca/users/B/mbrennan/node...
# 3   https://www.lakeheadu.ca/users/B/tbrown5/node/...
# 4   https://www.lakeheadu.ca/users/C/fchapman/node...
# 5   https://www.lakeheadu.ca/users/D/dwdylan/node/...
# 6   https://www.lakeheadu.ca/users/E/mezeudu/node/...
# 7   https://www.lakeheadu.ca/users/H/jhughe11/node...
# 8   https://www.lakeheadu.ca/users/L/plord/node/66558
# 9   https://www.lakeheadu.ca/users/P/wparkes/node/...
# 10  https://www.lakeheadu.ca/users/R/drosenbe/node...
# 11  https://www.lakeheadu.ca/users/S/ssama/node/57002
# 12  https://www.lakeheadu.ca/users/S/lspeak/node/7...
# 13  https://www.lakeheadu.ca/users/W/rwhitehe/node...
#
#                                                   bio listed_research_areas
# 0   Academic Qualifications:  Professor Alford rec...                  None
# 1   Academic Qualifications:  PhD Candidate - Pete...                  None
# 2   Academic Qualifications:  Dr. Brennan complete...                  None
# 3   Academic Qualifications:  LLB (Scots, Honours)...                  None
# 4   Academic Qualifications:  Dr. Chapman was admi...                  None
# 5   Academic Qualifications:  LL.M. (University of...                  None
# 6   Academic Qualifications:  Dr. Martin-Joe Ezeud...                  None
# 7   Academic Qualifications:  M.A., Ph.D. (Erlange...                  None
# 8   Phil Lord Assistant Professor Department: Bora...                  None
# 9   Academic Qualifications:  Professor Parkes has...                  None
# 10  Academic Qualifications:  Hons. B.A. from the ...                  None
# 11  Academic Qualifications:  Ph.D. (University of...                  None
# 12  Larissa Speak Assistant Professor Department: ...                  None
# 13  Robin Whitehead Assistant Professor Department...                  None

# %% [markdown]
# ### (8) University of Ottawa (Common Law)

# %%
base_url = 'https://www.uottawa.ca/faculty-law/common-law/'

# get english law faculty
request = requests.get(base_url + '/full-time-permanent-english-program-professors')
soup = BeautifulSoup(request.text, 'html.parser')
profs = soup.find_all('div', {'class': 'grid__col grid__col-m--9 grid__col-lw--8'})

# get french law faculty
request = requests.get(base_url + '/full-time-permanent-french-program-professors')
soup = BeautifulSoup(request.text, 'html.parser')
profs2 = soup.find_all('div', {'class': 'grid__col grid__col-m--9 grid__col-lw--8'})

profs = profs + profs2

def decrypt(encrypted):
    try:
        r = int(encrypted[:2],16)
        email = ''.join([chr(int(encrypted[i:i+2], 16) ^ r) for i in range(2, len(encrypted), 2)])
        return email
    except (ValueError):
         return None

results = []
for prof in profs:
    result = {}

    name = prof.find('h3').text
    name = name.split(',')[1].strip() + ' ' + name.split(',')[0].strip()

    title = prof.find('p').text
    title = title.replace(u'\xa0', u' ')
    title = title.replace('[email protected]', '')
    title = title.replace('(on leave)', '')
    title = title.strip()

    email = prof.find('a')
    if email:
        email = email['href']
        if '#' in email:
            email = email.split('#')[1]  
            email = decrypt(email).strip()
            email = email.replace('%20', '')
        else:
            email = None
    else:
        email = None

    if email:
        href = prof.find_all('a')[1]['href']
    else:
        href = prof.find_all('a')[0]['href']

    result['faculty'] = 'uottawa-common'
    result['name'] = name
    result['title'] = title
    result['email'] = email
    result['href'] = href

    results.append(result)

df = pd.DataFrame(results)

# if 'Emerit' in title, remove row
df = df[~df['title'].str.contains('Emerit')]

df
# Out:
#            faculty                 name  \
# 0   uottawa-common      Hassan M. Ahmad
# 1   uottawa-common         Amir Attaran
# 2   uottawa-common  Constance Backhouse
# 3   uottawa-common          Jane Bailey
# 4   uottawa-common        Natasha Bakht
# ..             ...                  ...
# 70  uottawa-common       Darren O'Toole
# 71  uottawa-common         Alain Roussy
# 72  uottawa-common        Teresa Scassa
# 73  uottawa-common     Stéphane Sérafin
# 74  uottawa-common         Joao Velloso
#
#                                                 title  \
# 0                               Replacement Professor
# 1                                      Full Professor
# 2                                      Full Professor
# 3                                      Full Professor
# 4                                      Full Professor
# ..                                                ...
# 70                                Associate Professor
# 71  Vice-Dean of the French Common Law Program and...
# 72                                     Full Professor
# 73                                Assistant Professor
# 74                                Associate Professor
#
#                              email  \
# 0                hahmad@uottawa.ca
# 1              aattaran@uOttawa.ca
# 2   Constance.Backhouse@uOttawa.ca
# 3           Jane.Bailey@uOttawa.ca
# 4         Natasha.Bakht@uOttawa.ca
# ..                             ...
# 70                            None
# 71              aroussy@uOttawa.ca
# 72        Teresa.Scassa@uOttawa.ca
# 73     stephane.serafin@uottawa.ca
# 74         joao.velloso@uOttawa.ca
#
#                                                  href
# 0   https://www.uottawa.ca/faculty-law/common-law/...
# 1   https://www.uottawa.ca/faculty-law/common-law/...
# 2   https://www.uottawa.ca/faculty-law/common-law/...
# 3   https://www.uottawa.ca/faculty-law/common-law/...
# 4   https://www.uottawa.ca/faculty-law/common-law/...
# ..                                                ...
# 70  https://www.uottawa.ca/faculty-law/common-law/...
# 71  https://www.uottawa.ca/faculty-law/common-law/...
# 72  https://www.uottawa.ca/faculty-law/common-law/...
# 73  https://www.uottawa.ca/faculty-law/common-law/...
# 74  https://www.uottawa.ca/faculty-law/common-law/...
#
# [74 rows x 5 columns]

# %%
# get bios from each href
def get_bio(row):
    response = requests.get(row['href'])
    soup = BeautifulSoup(response.text, 'html.parser')
    bio = soup.find('div', {'class': 'article-body-left__container'}).text
    bio = bio.replace(u'\xa0', u' ')
    bio = bio.replace('\n', ' ')
    bio = ' '.join(bio.split()).strip()
    if bio.startswith('Twitter') or bio.startswith('@') or bio.startswith('http'):
        bio = soup.find_all('div', {'class': 'article-body-left__container'})[1].text
        bio = bio.replace(u'\xa0', u' ')
        bio = bio.replace('\n', ' ')
        bio = ' '.join(bio.split()).strip()
    row['bio'] = bio
    row['listed_research_areas'] = None
    # NOTE: Some bios include research areas, but no consistent form
    # so will need to use NLP

    return row

df = df.apply(get_bio, axis=1)

# save to json
df.to_json(json_outpath + 'uottawa-common_bios.json', orient='records', indent = 2)

df
# Out:
#            faculty                 name  \
# 0   uottawa-common      Hassan M. Ahmad
# 1   uottawa-common         Amir Attaran
# 2   uottawa-common  Constance Backhouse
# 3   uottawa-common          Jane Bailey
# 4   uottawa-common        Natasha Bakht
# ..             ...                  ...
# 70  uottawa-common       Darren O'Toole
# 71  uottawa-common         Alain Roussy
# 72  uottawa-common        Teresa Scassa
# 73  uottawa-common     Stéphane Sérafin
# 74  uottawa-common         Joao Velloso
#
#                                                 title  \
# 0                               Replacement Professor
# 1                                      Full Professor
# 2                                      Full Professor
# 3                                      Full Professor
# 4                                      Full Professor
# ..                                                ...
# 70                                Associate Professor
# 71  Vice-Dean of the French Common Law Program and...
# 72                                     Full Professor
# 73                                Assistant Professor
# 74                                Associate Professor
#
#                              email  \
# 0                hahmad@uottawa.ca
# 1              aattaran@uOttawa.ca
# 2   Constance.Backhouse@uOttawa.ca
# 3           Jane.Bailey@uOttawa.ca
# 4         Natasha.Bakht@uOttawa.ca
# ..                             ...
# 70                            None
# 71              aroussy@uOttawa.ca
# 72        Teresa.Scassa@uOttawa.ca
# 73     stephane.serafin@uottawa.ca
# 74         joao.velloso@uOttawa.ca
#
#                                                  href  \
# 0   https://www.uottawa.ca/faculty-law/common-law/...
# 1   https://www.uottawa.ca/faculty-law/common-law/...
# 2   https://www.uottawa.ca/faculty-law/common-law/...
# 3   https://www.uottawa.ca/faculty-law/common-law/...
# 4   https://www.uottawa.ca/faculty-law/common-law/...
# ..                                                ...
# 70  https://www.uottawa.ca/faculty-law/common-law/...
# 71  https://www.uottawa.ca/faculty-law/common-law/...
# 72  https://www.uottawa.ca/faculty-law/common-law/...
# 73  https://www.uottawa.ca/faculty-law/common-law/...
# 74  https://www.uottawa.ca/faculty-law/common-law/...
#
#                                                   bio listed_research_areas
# 0   Hassan M. Ahmad is a scholar, advocate, and ac...                  None
# 1   Amir Attaran is an Professor in the Faculties ...                  None
# 2   Professor Backhouse holds the position of Dist...                  None
# 3   Jane Bailey is a Full Professor in the Common ...                  None
# 4   SSRN page Natasha Bakht is a Full Professor of...                  None
# ..                                                ...                   ...
# 70  Professor O’Toole teaches Aboriginal Law, Indi...                  None
# 71  Alain Roussy is currently Vice-Dean of the Fre...                  None
# 72  Dr. Teresa Scassa is the Canada Research Chair...                  None
# 73  Stéphane Sérafin is a graduate of the Programm...                  None
# 74  João Velloso teaches sentencing and “sanctioni...                  None
#
# [74 rows x 7 columns]

# %% [markdown]
# ### (9) Scrape University of Ottawa Faculty of Law - Civil Law
#
# NOTE: Some of these are in French, others in English.
#
# NOTE2: These are the least reliable, because there are several different inconsistent formats.
# Consider not using if relying heavily on bios.

# %%
base_url = 'https://www.uottawa.ca/faculte-droit/droit-civil/corps-professoral'

request = requests.get(base_url)
soup = BeautifulSoup(request.text, 'html.parser')
profs = soup.find_all('div', {'class': 'grid__col grid__col-m--9 grid__col-lw--8'})

def decrypt(encrypted):
    try:
        r = int(encrypted[:2],16)
        email = ''.join([chr(int(encrypted[i:i+2], 16) ^ r) for i in range(2, len(encrypted), 2)])
        return email
    except (ValueError):
         return None

results = []
for prof in profs:
    result = {}

    name = prof.find('h3').text
    name = name.split(',')[1].strip() + ' ' + name.split(',')[0].strip()

    title = prof.find('p').text
    title = title.replace(u'\xa0', u' ')
    title = title.replace('[email protected]', '')
    title = title.replace('(en congé)', '')
    title = title.strip()

    email = prof.find('a')
    if email:
        email = email['href']
        if '#' in email:
            email = email.split('#')[1]
            email = decrypt(email).strip()
            email = email.replace('%20', '')
        else:
            email = None
    else:
        email = None

    if email:
        href = prof.find_all('a')[1]['href']
    else:
        href = prof.find_all('a')[0]['href']

    result['faculty'] = 'uottawa-civil'
    result['name'] = name
    result['title'] = title
    result['email'] = email
    result['href'] = href

    results.append(result)

df = pd.DataFrame(results)

# if 'Personnel' in title, remove row
df = df[~df['title'].str.contains('Personnel')]

df
# Out:
#           faculty                      name  \
# 0   uottawa-civil            André Bélanger
# 1   uottawa-civil   Sarah Berger Richardson
# 2   uottawa-civil       Emmanuelle Bernheim
# 3   uottawa-civil            Thomas Burelli
# 4   uottawa-civil             Vincent Caron
# 5   uottawa-civil     Céline Castets-Renard
# 6   uottawa-civil      Naivi Chikoc Barreda
# 7   uottawa-civil  Pascale Cornut St-Pierre
# 8   uottawa-civil   Anne-Francoise Debruche
# 10  uottawa-civil          Patrick Dumberry
# 11  uottawa-civil               Karen Eltis
# 12  uottawa-civil           Jabeur Fathally
# 13  uottawa-civil     Audrey Ferron Parayre
# 14  uottawa-civil       Marie-France Fortin
# 15  uottawa-civil          Pascale Fournier
# 16  uottawa-civil          Margarida Garcia
# 17  uottawa-civil           Michelle Giroux
# 18  uottawa-civil         Mistrale Goudreau
# 19  uottawa-civil           Lynda Hubert Ta
# 20  uottawa-civil           Mariève Lacroix
# 21  uottawa-civil           Céline Lévesque
# 22  uottawa-civil          Pascal McDougall
# 23  uottawa-civil              Denis Nadeau
# 24  uottawa-civil             Ghislain Otis
# 25  uottawa-civil              Peter Oliver
# 26  uottawa-civil                Eva Ottawa
# 27  uottawa-civil               John Packer
# 28  uottawa-civil   Charles-Maxime Panaccio
# 29  uottawa-civil              Julie Paquin
# 30  uottawa-civil          Muriel Paradelle
# 31  uottawa-civil                 Mona Paré
# 32  uottawa-civil          Benoît Pelletier
# 33  uottawa-civil            Jennifer Quaid
# 34  uottawa-civil          David Robitaille
# 35  uottawa-civil             Terry Skolnik
# 36  uottawa-civil       Marie-Eve Sylvestre
# 37  uottawa-civil          Sophie Thériault
# 38  uottawa-civil              Joao Velloso
#
#                                                 title  \
# 0                                Professeur titulaire
# 1                                Professeure adjointe
# 2                               Professeure titulaire
# 3                                   Professeur agrégé
# 4                                   Professeur agrégé
# 5                               Professeure titulaire
# 6                                Professeure adjointe
# 7                                 Professeure agrégée
# 8                                 Professeure agrégée
# 10                               Professeur titulaire
# 11                              Professeure titulaire
# 12                                  Professeur agrégé
# 13                                Professeure agrégée
# 14                               Professeure adjointe
# 15                              Professeure titulaire
# 16                              Professeure titulaire
# 17                              Professeure titulaire
# 18                              Professeure titulaire
# 19                               Professeure adjointe
# 20                              Professeure titulaire
# 21                              Professeure titulaire
# 22                                 Professeur adjoint
# 23                               Professeur titulaire
# 24                               Professeur titulaire
# 25                               Professeur titulaire
# 26                               Professeure adjointe
# 27  Directeur du Centre de recherche et d’enseigne...
# 28                                  Professeur agrégé
# 29                                Professeure agrégée
# 30                                Professeure agrégée
# 31                              Professeure titulaire
# 32                               Professeur titulaire
# 33  Professeure agrégée et vice-doyenne à la reche...
# 34                               Professeur titulaire
# 35                                  Professeur agrégé
# 36                     Doyenne, professeure titulaire
# 37   Vice doyenne aux études et professeure titulaire
# 38                                  Professeur agrégé
#
#                                  email  \
# 0            andre.belanger@uottawa.ca
# 1    sarah.bergerrichardson@uottawa.ca
# 2                  ebernhe2@uottawa.ca
# 3                  tburelli@uottawa.ca
# 4             vincent.caron@uOttawa.ca
# 5     celine.castets-renard@uottawa.ca
# 6                  nchikocb@uottawa.ca
# 7   pascale.cornutst-pierre@uottawa.ca
# 8   Anne-Francoise.Debruche@uOttawa.ca
# 10                 pdumberr@uottawa.ca
# 11              Karen.Eltis@uOttawa.ca
# 12          jabeur.fathally@uOttawa.ca
# 13           audrey.parayre@uottawa.ca
# 14      marie-france.fortin@uOttawa.ca
# 15         Pascale.Fournier@uOttawa.ca
# 16                  mgarcia@uOttawa.ca
# 17          Michelle.Giroux@uOttawa.ca
# 18        Mistrale.Goudreau@uottawa.ca
# 19                 lhubertt@uottawa.ca
# 20          marieve.lacroix@uottawa.ca
# 21          Celine.Levesque@uOttawa.ca
# 22         pascal.mcdougall@uottawa.ca
# 23             Denis.Nadeau@uOttawa.ca
# 24            Ghislain.Otis@uOttawa.ca
# 25             Peter.Oliver@uOttawa.ca
# 26               eva.ottawa@uottawa.ca
# 27                  jpacker@uOttawa.ca
# 28  Charles-Maxime.Panaccio@uottawa.ca
# 29                  jpaqui4@uottawa.ca
# 30       Murielle.Paradelle@uOttawa.ca
# 31                mona.pare@uottawa.ca
# 32         Benoit.Pelletier@uOttawa.ca
# 33           Jennifer.Quaid@uottawa.ca
# 34         david.robitaille@uottawa.ca
# 35                 tskolnik@uottawa.ca
# 36      Marie-Eve.Sylvestre@uottawa.ca
# 37         Sophie.Theriault@uOttawa.ca
# 38             joao.velloso@uottawa.ca
#
#                                                  href
# 0      https://uniweb.uottawa.ca/members/4708/profile
# 1      https://uniweb.uottawa.ca/members/4299/profile
# 2      https://uniweb.uottawa.ca/members/4302/profile
# 3   https://www.uottawa.ca/faculte-droit/droit-civ...
# 4   https://www.uottawa.ca/faculte-droit/droit-civ...
# 5      https://uniweb.uottawa.ca/members/4949/profile
# 6      https://uniweb.uottawa.ca/members/4845/profile
# 7   https://www.uottawa.ca/faculte-droit/droit-civ...
# 8   https://www.uottawa.ca/faculte-droit/droit-civ...
# 10     https://uniweb.uottawa.ca/members/4803/profile
# 11  https://www.uottawa.ca/faculte-droit/droit-civ...
# 12  https://www.uottawa.ca/faculte-droit/droit-civ...
# 13             https://uniweb.uottawa.ca/members/4739
# 14     https://uniweb.uottawa.ca/members/5112/profile
# 15  https://www.uottawa.ca/faculte-droit/droit-civ...
# 16  https://www.uottawa.ca/faculte-droit/droit-civ...
# 17  https://www.uottawa.ca/faculte-droit/droit-civ...
# 18     https://uniweb.uottawa.ca/members/2612/profile
# 19  https://www.uottawa.ca/faculte-droit/droit-civ...
# 20     https://uniweb.uottawa.ca/members/4788/profile
# 21  https://www.uottawa.ca/faculte-droit/droit-civ...
# 22  https://www.uottawa.ca/faculte-droit/droit-civ...
# 23  https://www.uottawa.ca/faculte-droit/droit-civ...
# 24  https://www.uottawa.ca/faculte-droit/droit-civ...
# 25  https://www.uottawa.ca/faculte-droit/droit-civ...
# 26  https://www.uottawa.ca/faculte-droit/droit-civ...
# 27  https://www.uottawa.ca/faculte-droit/common-la...
# 28  https://www.uottawa.ca/faculte-droit/droit-civ...
# 29      https://uniweb.uottawa.ca/members/409/profile
# 30  https://www.uottawa.ca/faculte-droit/droit-civ...
# 31     https://uniweb.uottawa.ca/members/4768/profile
# 32  https://www.uottawa.ca/faculte-droit/droit-civ...
# 33  https://www.uottawa.ca/faculte-droit/droit-civ...
# 34     https://uniweb.uottawa.ca/members/1670/profile
# 35     https://uniweb.uottawa.ca/members/4305/profile
# 36  https://www.uottawa.ca/faculte-droit/droit-civ...
# 37  https://www.uottawa.ca/faculte-droit/droit-civ...
# 38  https://www.uottawa.ca/faculte-droit/common-la...

# %%
# This is a bit of a mess, it's not capturing everyighing, and it's likely to break
# If using bios, consider excluding Ottawa Civil Law

# get bios from each href
def get_bio(row):
    bio = None # reset just in case
    if 'uniweb' in row['href']:
        link = row['href']
        link = link.split('/profile')[0]
        link = link.split('/')[-1]
        link = f'https://uniweb.uottawa.ca/profiles.php?action=display&editable=false&contentType=members&contentId={link}&viewType=profile&withFormat=true'
        response = requests.get(link)
        data = response.json()
        try:
            # check if the entire ['sections'][2]['items'][0]['values']['1341'] exists 
            bio = data['sections'][2]['items'][0]['values']['1341']
            bio_json = json.loads(bio)
            # check if bio_json has 'en' or 'fr' key
            if 'en' in bio_json:
                bio = bio_json['en']
            elif 'fr' in bio_json:
                bio = bio_json['fr']
            else:
                bio = None
        except (KeyError, IndexError):
            try:
                # check if the entire ['sections'][8]['items'][0]['values']['1352'] exists 
                bio = data['sections'][8]['items'][0]['values']['1352']
                bio_json = json.loads(bio)
                # check if bio_json has 'en' or 'fr' key
                if 'en' in bio_json:
                    bio = bio_json['en']
                elif 'fr' in bio_json:
                    bio = bio_json['fr']
                else:
                    bio = None
            except (KeyError, IndexError):
                bio = None

    else:    
        response = requests.get(row['href'])
        soup = BeautifulSoup(response.text, 'html.parser')
        bio = soup.find('div', {'class': 'article-body-left__container'}).text
        bio = bio.replace(u'\xa0', u' ')
        bio = bio.replace('\n', ' ')
        bio = ' '.join(bio.split()).strip()
        if bio.startswith('Twitter') or bio.startswith('@') or bio.startswith('http') or bio.startswith('SSRN Twitter'):
            bio = soup.find_all('div', {'class': 'article-body-left__container'})[1].text
            bio = bio.replace(u'\xa0', u' ')
            bio = bio.replace('\n', ' ')
            bio = ' '.join(bio.split()).strip()
        if bio == 'en préparation':
            bio = None
    row['bio'] = bio
    row['listed_research_areas'] = None
    # NOTE: Some bios include research areas, but no consistent form
    # so will need to use NLP

    return row

df = df.apply(get_bio, axis=1)

# save to json
df.to_json(json_outpath + 'uottawa-civil_bios.json', orient='records', indent = 2)

df
# Out:
#           faculty                      name  \
# 0   uottawa-civil            André Bélanger
# 1   uottawa-civil   Sarah Berger Richardson
# 2   uottawa-civil       Emmanuelle Bernheim
# 3   uottawa-civil            Thomas Burelli
# 4   uottawa-civil             Vincent Caron
# 5   uottawa-civil     Céline Castets-Renard
# 6   uottawa-civil      Naivi Chikoc Barreda
# 7   uottawa-civil  Pascale Cornut St-Pierre
# 8   uottawa-civil   Anne-Francoise Debruche
# 10  uottawa-civil          Patrick Dumberry
# 11  uottawa-civil               Karen Eltis
# 12  uottawa-civil           Jabeur Fathally
# 13  uottawa-civil     Audrey Ferron Parayre
# 14  uottawa-civil       Marie-France Fortin
# 15  uottawa-civil          Pascale Fournier
# 16  uottawa-civil          Margarida Garcia
# 17  uottawa-civil           Michelle Giroux
# 18  uottawa-civil         Mistrale Goudreau
# 19  uottawa-civil           Lynda Hubert Ta
# 20  uottawa-civil           Mariève Lacroix
# 21  uottawa-civil           Céline Lévesque
# 22  uottawa-civil          Pascal McDougall
# 23  uottawa-civil              Denis Nadeau
# 24  uottawa-civil             Ghislain Otis
# 25  uottawa-civil              Peter Oliver
# 26  uottawa-civil                Eva Ottawa
# 27  uottawa-civil               John Packer
# 28  uottawa-civil   Charles-Maxime Panaccio
# 29  uottawa-civil              Julie Paquin
# 30  uottawa-civil          Muriel Paradelle
# 31  uottawa-civil                 Mona Paré
# 32  uottawa-civil          Benoît Pelletier
# 33  uottawa-civil            Jennifer Quaid
# 34  uottawa-civil          David Robitaille
# 35  uottawa-civil             Terry Skolnik
# 36  uottawa-civil       Marie-Eve Sylvestre
# 37  uottawa-civil          Sophie Thériault
# 38  uottawa-civil              Joao Velloso
#
#                                                 title  \
# 0                                Professeur titulaire
# 1                                Professeure adjointe
# 2                               Professeure titulaire
# 3                                   Professeur agrégé
# 4                                   Professeur agrégé
# 5                               Professeure titulaire
# 6                                Professeure adjointe
# 7                                 Professeure agrégée
# 8                                 Professeure agrégée
# 10                               Professeur titulaire
# 11                              Professeure titulaire
# 12                                  Professeur agrégé
# 13                                Professeure agrégée
# 14                               Professeure adjointe
# 15                              Professeure titulaire
# 16                              Professeure titulaire
# 17                              Professeure titulaire
# 18                              Professeure titulaire
# 19                               Professeure adjointe
# 20                              Professeure titulaire
# 21                              Professeure titulaire
# 22                                 Professeur adjoint
# 23                               Professeur titulaire
# 24                               Professeur titulaire
# 25                               Professeur titulaire
# 26                               Professeure adjointe
# 27  Directeur du Centre de recherche et d’enseigne...
# 28                                  Professeur agrégé
# 29                                Professeure agrégée
# 30                                Professeure agrégée
# 31                              Professeure titulaire
# 32                               Professeur titulaire
# 33  Professeure agrégée et vice-doyenne à la reche...
# 34                               Professeur titulaire
# 35                                  Professeur agrégé
# 36                     Doyenne, professeure titulaire
# 37   Vice doyenne aux études et professeure titulaire
# 38                                  Professeur agrégé
#
#                                  email  \
# 0            andre.belanger@uottawa.ca
# 1    sarah.bergerrichardson@uottawa.ca
# 2                  ebernhe2@uottawa.ca
# 3                  tburelli@uottawa.ca
# 4             vincent.caron@uOttawa.ca
# 5     celine.castets-renard@uottawa.ca
# 6                  nchikocb@uottawa.ca
# 7   pascale.cornutst-pierre@uottawa.ca
# 8   Anne-Francoise.Debruche@uOttawa.ca
# 10                 pdumberr@uottawa.ca
# 11              Karen.Eltis@uOttawa.ca
# 12          jabeur.fathally@uOttawa.ca
# 13           audrey.parayre@uottawa.ca
# 14      marie-france.fortin@uOttawa.ca
# 15         Pascale.Fournier@uOttawa.ca
# 16                  mgarcia@uOttawa.ca
# 17          Michelle.Giroux@uOttawa.ca
# 18        Mistrale.Goudreau@uottawa.ca
# 19                 lhubertt@uottawa.ca
# 20          marieve.lacroix@uottawa.ca
# 21          Celine.Levesque@uOttawa.ca
# 22         pascal.mcdougall@uottawa.ca
# 23             Denis.Nadeau@uOttawa.ca
# 24            Ghislain.Otis@uOttawa.ca
# 25             Peter.Oliver@uOttawa.ca
# 26               eva.ottawa@uottawa.ca
# 27                  jpacker@uOttawa.ca
# 28  Charles-Maxime.Panaccio@uottawa.ca
# 29                  jpaqui4@uottawa.ca
# 30       Murielle.Paradelle@uOttawa.ca
# 31                mona.pare@uottawa.ca
# 32         Benoit.Pelletier@uOttawa.ca
# 33           Jennifer.Quaid@uottawa.ca
# 34         david.robitaille@uottawa.ca
# 35                 tskolnik@uottawa.ca
# 36      Marie-Eve.Sylvestre@uottawa.ca
# 37         Sophie.Theriault@uOttawa.ca
# 38             joao.velloso@uottawa.ca
#
#                                                  href  \
# 0      https://uniweb.uottawa.ca/members/4708/profile
# 1      https://uniweb.uottawa.ca/members/4299/profile
# 2      https://uniweb.uottawa.ca/members/4302/profile
# 3   https://www.uottawa.ca/faculte-droit/droit-civ...
# 4   https://www.uottawa.ca/faculte-droit/droit-civ...
# 5      https://uniweb.uottawa.ca/members/4949/profile
# 6      https://uniweb.uottawa.ca/members/4845/profile
# 7   https://www.uottawa.ca/faculte-droit/droit-civ...
# 8   https://www.uottawa.ca/faculte-droit/droit-civ...
# 10     https://uniweb.uottawa.ca/members/4803/profile
# 11  https://www.uottawa.ca/faculte-droit/droit-civ...
# 12  https://www.uottawa.ca/faculte-droit/droit-civ...
# 13             https://uniweb.uottawa.ca/members/4739
# 14     https://uniweb.uottawa.ca/members/5112/profile
# 15  https://www.uottawa.ca/faculte-droit/droit-civ...
# 16  https://www.uottawa.ca/faculte-droit/droit-civ...
# 17  https://www.uottawa.ca/faculte-droit/droit-civ...
# 18     https://uniweb.uottawa.ca/members/2612/profile
# 19  https://www.uottawa.ca/faculte-droit/droit-civ...
# 20     https://uniweb.uottawa.ca/members/4788/profile
# 21  https://www.uottawa.ca/faculte-droit/droit-civ...
# 22  https://www.uottawa.ca/faculte-droit/droit-civ...
# 23  https://www.uottawa.ca/faculte-droit/droit-civ...
# 24  https://www.uottawa.ca/faculte-droit/droit-civ...
# 25  https://www.uottawa.ca/faculte-droit/droit-civ...
# 26  https://www.uottawa.ca/faculte-droit/droit-civ...
# 27  https://www.uottawa.ca/faculte-droit/common-la...
# 28  https://www.uottawa.ca/faculte-droit/droit-civ...
# 29      https://uniweb.uottawa.ca/members/409/profile
# 30  https://www.uottawa.ca/faculte-droit/droit-civ...
# 31     https://uniweb.uottawa.ca/members/4768/profile
# 32  https://www.uottawa.ca/faculte-droit/droit-civ...
# 33  https://www.uottawa.ca/faculte-droit/droit-civ...
# 34     https://uniweb.uottawa.ca/members/1670/profile
# 35     https://uniweb.uottawa.ca/members/4305/profile
# 36  https://www.uottawa.ca/faculte-droit/droit-civ...
# 37  https://www.uottawa.ca/faculte-droit/droit-civ...
# 38  https://www.uottawa.ca/faculte-droit/common-la...
#
#                                                   bio listed_research_areas
# 0   Avant de joindre le corps professoral de la Se...                  None
# 1   My research focuses on the regulation of food ...                  None
# 2   My research focuses on the role of law and jus...                  None
# 3   Thomas Burelli donne le cours de Droit interna...                  None
# 4   Vincent Caron est professeur agrégé. Ses intér...                  None
# 5   <div>Céline Castets-Renard is the Research Cha...                  None
# 6   La professeure Chikoc Barreda s'intéresse au d...                  None
# 7   Pascale Cornut St-Pierre est professeure agrég...                  None
# 8   Anne-Françoise Debruche a étudié le droit civi...                  None
# 10  Patrick Dumberry, Ph.D. (Graduate Institute of...                  None
# 11  La professeure Karen Eltis est professeure tit...                  None
# 12  Member of the Bar of Ontario ( Barrister & sol...                  None
# 13  La professeure Ferron-Parayre s'intéresse glob...                  None
# 14                                               None                  None
# 15  Pascale Fournier est professeure titulaire à l...                  None
# 16  Margarida Garcia est professeure à la Faculté ...                  None
# 17  Michelle Giroux est professeure titulaire à la...                  None
# 18  Mistrale Goudreau est une spécialiste de propr...                  None
# 19  La nouvelle professeure en droit de l’entrepri...                  None
# 20  Les intérêts de recherche et d’enseignement en...                  None
# 21  Céline Lévesque est professeure à l’Université...                  None
# 22  Pascal McDougall est professeur adjoint à la S...                  None
# 23  Denis Nadeau est un spécialiste du droit du tr...                  None
# 24                                               None                  None
# 25  Le professeur Peter C. Oliver vise plusieurs e...                  None
# 26  Eva Ottawa est une chercheuse atikamekw nehiro...                  None
# 27  John Packer est professeur de droit agrégé et ...                  None
# 28  Charles-Maxime Panaccio est diplômé des univer...                  None
# 29                                               None                  None
# 30  Publications et Communications Monographies "D...                  None
# 31  Mona Paré's research interests include childre...                  None
# 32  Admis au Barreau du Québec en 1982, Benoît Pel...                  None
# 33  Jennifer Quaid est professeure agrégée et vice...                  None
# 34  David Robitaille est professeur titulaire à la...                  None
# 35  Terry Skolnik is an associate professor (tenur...                  None
# 36  Marie-Eve Sylvestre est doyenne et professeure...                  None
# 37  Sophie Thériault est professeure titulaire et ...                  None
# 38  Joao Velloso enseigne le droit des peines et d...                  None

# %% [markdown]
# ### Combine scraped data into a single file

# %%
# load Osgoode df
df = pd.read_json(json_outpath + 'osgoode_bios.json')

# add U of T df
tempdf = pd.read_json(json_outpath + 'u_toronto_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# add TMU df
tempdf = pd.read_json(json_outpath + 'tmu_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# add Queens df
tempdf = pd.read_json(json_outpath + 'queens_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# add Western df
tempdf = pd.read_json(json_outpath + 'western_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# add Windsor df
tempdf = pd.read_json(json_outpath + 'windsor_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# add Lakehead df
tempdf = pd.read_json(json_outpath + 'lakehead_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# Add U of Ottawa common law df
tempdf = pd.read_json(json_outpath + 'uottawa-common_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# Add U of Ottawa civil law df
tempdf = pd.read_json(json_outpath + 'uottawa-civil_bios.json')
df = pd.concat([df, tempdf], ignore_index=True)

# Save to json for future use
df.to_json(json_outpath + 'all_bios.json', orient='records', indent = 2)

df
# Out:
#            faculty                     name  \
# 0          osgoode            Rabiat Akande
# 1          osgoode  Saptarishi Bandopadhyay
# 2          osgoode      Stephanie Ben-Ishai
# 3          osgoode       Benjamin L. Berger
# 4          osgoode       Kate Glover Berger
# ..             ...                      ...
# 379  uottawa-civil         David Robitaille
# 380  uottawa-civil            Terry Skolnik
# 381  uottawa-civil      Marie-Eve Sylvestre
# 382  uottawa-civil         Sophie Thériault
# 383  uottawa-civil             Joao Velloso
#
#                                                  title  \
# 0                                  Assistant Professor
# 1                                  Associate Professor
# 2    Professor and York University Distinguished Re...
# 3    Professor & York Research Chair in Pluralism a...
# 4                                  Associate Professor
# ..                                                 ...
# 379                               Professeur titulaire
# 380                                  Professeur agrégé
# 381                     Doyenne, professeure titulaire
# 382   Vice doyenne aux études et professeure titulaire
# 383                                  Professeur agrégé
#
#                               email  \
# 0          rakande@osgoode.yorku.ca
# 1    sbandopadhyay@osgoode.yorku.ca
# 2        sbenishai@osgoode.yorku.ca
# 3          bberger@osgoode.yorku.ca
# 4         kgberger@osgoode.yorku.ca
# ..                              ...
# 379     david.robitaille@uottawa.ca
# 380             tskolnik@uottawa.ca
# 381  Marie-Eve.Sylvestre@uottawa.ca
# 382     Sophie.Theriault@uOttawa.ca
# 383         joao.velloso@uottawa.ca
#
#                                                   href  \
# 0    https://www.osgoode.yorku.ca/faculty-and-staff...
# 1    https://www.osgoode.yorku.ca/faculty-and-staff...
# 2    https://www.osgoode.yorku.ca/faculty-and-staff...
# 3    https://www.osgoode.yorku.ca/faculty-and-staff...
# 4    https://www.osgoode.yorku.ca/faculty-and-staff...
# ..                                                 ...
# 379     https://uniweb.uottawa.ca/members/1670/profile
# 380     https://uniweb.uottawa.ca/members/4305/profile
# 381  https://www.uottawa.ca/faculte-droit/droit-civ...
# 382  https://www.uottawa.ca/faculte-droit/droit-civ...
# 383  https://www.uottawa.ca/faculte-droit/common-la...
#
#                                                    bio  \
# 0    Professor Rabiat Akande works in the fields of...
# 1    I am an Associate Professor at Osgoode Hall La...
# 2    Professor Stephanie Ben-Ishai is a Distinguish...
# 3    Professor Benjamin L. Berger is Professor and ...
# 4    Professor Kate Glover Berger joined the facult...
# ..                                                 ...
# 379  David Robitaille est professeur titulaire à la...
# 380  Terry Skolnik is an associate professor (tenur...
# 381  Marie-Eve Sylvestre est doyenne et professeure...
# 382  Sophie Thériault est professeure titulaire et ...
# 383  Joao Velloso enseigne le droit des peines et d...
#
#                                  listed_research_areas
# 0    legal history; law and religion; constitutiona...
# 1    Law; history; and politics of Disasters; Inter...
# 2                             Corporate/Commercial Law
# 3    Law and Religion; Criminal and Constitutional ...
# 4                                                 None
# ..                                                 ...
# 379                                                NaN
# 380                                                NaN
# 381                                                NaN
# 382                                                NaN
# 383                                                NaN
#
# [384 rows x 7 columns]
